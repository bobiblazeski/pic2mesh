# %%
import torch
from torchsummary import summary

from fastgan import (
    Generator,
    Discriminator,
    SimpleDecoder,
    TextureDiscriminator,
)

# %%
#device = torch.device()
G = Generator(im_size=256)
G
# Out:
# Generator(
#   (init): InitLayer(
#     (init): Sequential(
#       (0): ConvTranspose2d(100, 2048, kernel_size=(4, 4), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): GLU()
#     )
#   )
#   (feat_8): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): NoiseInjection()
#     (3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): GLU()
#     (5): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (6): NoiseInjection()
#     (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): GLU()
#   )
#   (feat_16): Sequential(
#     (0): Upsample(scale_factor=2.0, mode=nearest)
#     (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
res = G(torch.rand(3, 100))
res[0].shape, res[1].shape
# Out:
# (torch.Size([3, 3, 256, 256]), torch.Size([3, 3, 128, 128]))

# %%
summary(G, (100,))
# Out:
# ------------------------------------------------------------------------------------------
# Layer (type:depth-idx)                   Output Shape              Param #
# ...
# ├─InitLayer: 1-1                         [-1, 1024, 4, 4]          --
# |    └─Sequential: 2-1                   [-1, 1024, 4, 4]          --
# |    |    └─ConvTranspose2d: 3-1         [-1, 2048, 4, 4]          3,276,800
# |    |    └─BatchNorm2d: 3-2             [-1, 2048, 4, 4]          4,096
# |    |    └─GLU: 3-3                     [-1, 1024, 4, 4]          --
# ├─Sequential: 1-2                        [-1, 512, 8, 8]           --
# |    └─Upsample: 2-2                     [-1, 1024, 8, 8]          --
# |    └─Conv2d: 2-3                       [-1, 1024, 8, 8]          9,437,184
# |    └─NoiseInjection: 2-4               [-1, 1024, 8, 8]          1
# |    └─BatchNorm2d: 2-5                  [-1, 1024, 8, 8]          2,048
# |    └─GLU: 2-6                          [-1, 512, 8, 8]           --
# ...

# %%
D = Discriminator(im_size=256)
D
# Out:
# Discriminator(
#   (down_from_big): Sequential(
#     (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (down_4): DownBlockComp(
#     (main): Sequential(
#       (0): Conv2d(16, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2, inplace=True)
#       (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): LeakyReLU(negative_slope=0.2)
#     )
#     (direct): Sequential(
#       (0): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       (1): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
D(res, label='fake').shape
# Out:
# torch.Size([150])

# %%
dres  = D(res, label='real')
dres[0].shape
# Out:
# torch.Size([150])

# %%
dres[1][0].shape, dres[1][1].shape, dres[1][2].shape
# Out:
# (torch.Size([3, 3, 128, 128]),
#  torch.Size([3, 3, 128, 128]),
#  torch.Size([3, 3, 128, 128]))

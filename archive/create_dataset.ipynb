# %%
import numpy as np
import trimesh
import open3d as o3d
import torch
import os
import glob


from polar_traversal import gather_all_paths, sample_all_paths

np.set_printoptions(precision=4, suppress=True)
torch.set_printoptions(precision=4, sci_mode=False)

# %%
stl_dir = "./data/stls/"
stls = [os.path.join(stl_dir, f) 
        for f in os.listdir(stl_dir) 
        if f.endswith(".stl")]

stls.sort()
# Problems 26, 45, 69
idx = 26
file_name = stls[idx]
print(idx, file_name)
latitudes_num = 1024
paths = gather_all_paths(file_name, latitudes_num)
print(len(paths))

samples_num = 256
samples = sample_all_paths(paths, samples_num)
print(samples.shape)
# Out:
# 26 ./data/stls/catherine_hidden_agenda.stl
# 1024
# (512, 512, 3)

# %%
points = samples.reshape(-1, 3)
pcd = o3d.geometry.PointCloud()
pcd.points = o3d.utility.Vector3dVector(points)    
o3d.visualization.draw_geometries([pcd])

# %%
samples.shape
# Out:
# (512, 512, 3)

# %%
# Out:
# 'catherine_hidden_agenda.npz'

# %%
file = stls[idx].split('/')[-1].replace('.stl', '.npz')
np.savez_compressed('./data/512/'+file, samples=samples)

# %%
latitudes_num = 1024
samples_num = 256

for idx, stl in enumerate(stls):
    print(idx, stl)
    file_name = stls[idx]
    print(idx, file_name)    
    paths = gather_all_paths(file_name, latitudes_num)
    samples = sample_all_paths(paths, samples_num)
    file = file_name.split('/')[-1].replace('.stl', '.npz')
    np.savez_compressed('./data/512/'+file, samples=samples)
# Out:
# 0 ./data/stls/abe_white_inpatient.stl
# 0 ./data/stls/abe_white_inpatient.stl
# 1 ./data/stls/abigaile_ortiz_tomb_raider.stl
# 1 ./data/stls/abigaile_ortiz_tomb_raider.stl
# 2 ./data/stls/ada_wong_resident_evil.stl
# 2 ./data/stls/ada_wong_resident_evil.stl
# 3 ./data/stls/administrator_evil_within.stl
# 3 ./data/stls/administrator_evil_within.stl
# 4 ./data/stls/aidan_overkill_walking_dead.stl
# 4 ./data/stls/aidan_overkill_walking_dead.stl
# 5 ./data/stls/aloy_horizon_zero_dawn.stl
# 5 ./data/stls/aloy_horizon_zero_dawn.stl
# 6 ./data/stls/amelia_croft_tomb_raider.stl
# 6 ./data/stls/amelia_croft_tomb_raider.stl
# 7 ./data/stls/anakin_skywalker_battlefront_2.stl
# 7 ./data/stls/anakin_skywalker_battlefront_2.stl
# 8 ./data/stls/angela_civilian_detroit.stl
# 8 ./data/stls/angela_civilian_detroit.stl
# 9 ./data/stls/annie_dead_rising.stl
# 9 ./data/stls/annie_dead_rising.stl
# 10 ./data/stls/anya_gears_of_war.stl
# 10 ./data/stls/anya_gears_of_war.stl
# 11 ./data/stls/aphrodite_ascendant_one.stl
# 11 ./data/stls/aphrodite_ascendant_one.stl
# 12 ./data/stls/aranea_highwind_final_fantasy.stl
# 12 ./data/stls/aranea_highwind_final_fantasy.stl
# 13 ./data/stls/ares_ascendant_one.stl
# 13 ./data/stls/ares_ascendant_one.stl
# 14 ./data/stls/artemis_ascendant_one.stl
# 14 ./data/stls/artemis_ascendant_one.stl
# 15 ./data/stls/athena_ascendant_one.stl
# 15 ./data/stls/athena_ascendant_one.stl
# 16 ./data/stls/badgirl_no_more_heroes.stl
# 16 ./data/stls/badgirl_no_more_heroes.stl
# 17 ./data/stls/badman_no_more_heroes.stl
# 17 ./data/stls/badman_no_more_heroes.stl
# 18 ./data/stls/becky_hidden_agenda.stl
# 18 ./data/stls/becky_hidden_agenda.stl
# 19 ./data/stls/black_lightning_injustice_2.stl
# 19 ./data/stls/black_lightning_injustice_2.stl
# 20 ./data/stls/bridger_overkill_walking_dead.stl
# 20 ./data/stls/bridger_overkill_walking_dead.stl
# 21 ./data/stls/caligo_ulldor_final_fantasy.stl
# 21 ./data/stls/caligo_ulldor_final_fantasy.stl
# 22 ./data/stls/camelia_claustra_final_fantasy.stl
# 22 ./data/stls/camelia_claustra_final_fantasy.stl
# 23 ./data/stls/cameron_burke_far_cry.stl
# 23 ./data/stls/cameron_burke_far_cry.stl
# 24 ./data/stls/carl_detroit.stl
# 24 ./data/stls/carl_detroit.stl
# 25 ./data/stls/cassie_drake_uncharted.stl
# 25 ./data/stls/cassie_drake_uncharted.stl
# 26 ./data/stls/catherine_hidden_agenda.stl
# 26 ./data/stls/catherine_hidden_agenda.stl
# 27 ./data/stls/chloe_detroit.stl
# 27 ./data/stls/chloe_detroit.stl
# 28 ./data/stls/cid_sophiar_final_fantasy.stl
# 28 ./data/stls/cid_sophiar_final_fantasy.stl
# 29 ./data/stls/cindy_aurum_final_fantasy.stl
# 29 ./data/stls/cindy_aurum_final_fantasy.stl
# 30 ./data/stls/claire_resident_evil.stl
# 30 ./data/stls/claire_resident_evil.stl
# 31 ./data/stls/clara_odea_assassins_creed.stl
# 31 ./data/stls/clara_odea_assassins_creed.stl
# 32 ./data/stls/connor_detroit.stl
# 32 ./data/stls/connor_detroit.stl
# 33 ./data/stls/cor_leonis_final_fantasy.stl
# 33 ./data/stls/cor_leonis_final_fantasy.stl
# 34 ./data/stls/dante_dmc.stl
# 34 ./data/stls/dante_dmc.stl
# 35 ./data/stls/dengar_battlefront_2.stl
# 35 ./data/stls/dengar_battlefront_2.stl
# 36 ./data/stls/dino_ghiranze_final_fantasy.stl
# 36 ./data/stls/dino_ghiranze_final_fantasy.stl
# 37 ./data/stls/dooku_battlefront_2.stl
# 37 ./data/stls/dooku_battlefront_2.stl
# 38 ./data/stls/earl_whitehorse_far_cry.stl
# 38 ./data/stls/earl_whitehorse_far_cry.stl
# 39 ./data/stls/eden_girl_detroit.stl
# 39 ./data/stls/eden_girl_detroit.stl
# 40 ./data/stls/egon_spengler_ghostbusters.stl
# 40 ./data/stls/egon_spengler_ghostbusters.stl
# 41 ./data/stls/elena_fisher_uncharted.stl
# 41 ./data/stls/elena_fisher_uncharted.stl
# 42 ./data/stls/elisa_two_souls.stl
# 42 ./data/stls/elisa_two_souls.stl
# 43 ./data/stls/elise_child_assassins_creed.stl
# 43 ./data/stls/elise_child_assassins_creed.stl
# 44 ./data/stls/ellie_last_of_us.stl
# 44 ./data/stls/ellie_last_of_us.stl
# 45 ./data/stls/enchantress_injustice_2.stl
# 45 ./data/stls/enchantress_injustice_2.stl
# 46 ./data/stls/esmeralda_torres_evil_within.stl
# 46 ./data/stls/esmeralda_torres_evil_within.stl
# 47 ./data/stls/ethan_mars_heavy_rain.stl
# 47 ./data/stls/ethan_mars_heavy_rain.stl
# 48 ./data/stls/faith_seed_far_cry.stl
# 48 ./data/stls/faith_seed_far_cry.stl
# 49 ./data/stls/felicity_hidden_agenda.stl
# 49 ./data/stls/felicity_hidden_agenda.stl
# 50 ./data/stls/flash_injustice_2.stl
# 50 ./data/stls/flash_injustice_2.stl
# 51 ./data/stls/frank_west_dead_rising.stl
# 51 ./data/stls/frank_west_dead_rising.stl
# 52 ./data/stls/gentiana_final_fantasy.stl
# 52 ./data/stls/gentiana_final_fantasy.stl
# 53 ./data/stls/grace_armstrong_far_cry.stl
# 53 ./data/stls/grace_armstrong_far_cry.stl
# 54 ./data/stls/grant_overkill_walking_dead.stl
# 54 ./data/stls/grant_overkill_walking_dead.stl
# 55 ./data/stls/green_lantern_injustice_2.stl
# 55 ./data/stls/green_lantern_injustice_2.stl
# 56 ./data/stls/gus_gears_of_war.stl
# 56 ./data/stls/gus_gears_of_war.stl
# 57 ./data/stls/han_solo_battlefront_2.stl
# 57 ./data/stls/han_solo_battlefront_2.stl
# 58 ./data/stls/han_solo_young_battlefront_2.stl
# 58 ./data/stls/han_solo_young_battlefront_2.stl
# 59 ./data/stls/hank_detroit.stl
# 59 ./data/stls/hank_detroit.stl
# 60 ./data/stls/harley_quinn_injustice_2.stl
# 60 ./data/stls/harley_quinn_injustice_2.stl
# 61 ./data/stls/heather_overkill_walking_dead.stl
# 61 ./data/stls/heather_overkill_walking_dead.stl
# 62 ./data/stls/hebe_ascendant_one.stl
# 62 ./data/stls/hebe_ascendant_one.stl
# 63 ./data/stls/helen_dawkins_two_souls.stl
# 63 ./data/stls/helen_dawkins_two_souls.stl
# 64 ./data/stls/henry_last_of_us.stl
# 64 ./data/stls/henry_last_of_us.stl
# 65 ./data/stls/hera_ascendant_one.stl
# 65 ./data/stls/hera_ascendant_one.stl
# 66 ./data/stls/hero_uncharted.stl
# 66 ./data/stls/hero_uncharted.stl
# 67 ./data/stls/hoffman_gears_of_war.stl
# 67 ./data/stls/hoffman_gears_of_war.stl
# 68 ./data/stls/hunter_thibodeaux_dead_rising.stl
# 68 ./data/stls/hunter_thibodeaux_dead_rising.stl
# 69 ./data/stls/iason_ascendant_one.stl
# 69 ./data/stls/iason_ascendant_one.stl
# 70 ./data/stls/iden_versio_battlefront_2.stl
# 70 ./data/stls/iden_versio_battlefront_2.stl
# 71 ./data/stls/ignis_scientia_final_fantasy.stl
# 71 ./data/stls/ignis_scientia_final_fantasy.stl
# 72 ./data/stls/ilyssa_selwyn_ghostbusters.stl
# 72 ./data/stls/ilyssa_selwyn_ghostbusters.stl
# 73 ./data/stls/iris_amicitia_final_fantasy.stl
# 73 ./data/stls/iris_amicitia_final_fantasy.stl
# 74 ./data/stls/iris_ascendant_one.stl
# 74 ./data/stls/iris_ascendant_one.stl
# 75 ./data/stls/isabela_keyes_dead_rising.stl
# 75 ./data/stls/isabela_keyes_dead_rising.stl
# 76 ./data/stls/jace_gears_of_war.stl
# 76 ./data/stls/jace_gears_of_war.stl
# 77 ./data/stls/jacob_seed_far_cry.stl
# 77 ./data/stls/jacob_seed_far_cry.stl
# 78 ./data/stls/janine_melnitz_ghostbusters.stl
# 78 ./data/stls/janine_melnitz_ghostbusters.stl
# 79 ./data/stls/jared_hester_final_fantasy.stl
# 79 ./data/stls/jared_hester_final_fantasy.stl
# 80 ./data/stls/jefferson_bragg_inpatient.stl
# 80 ./data/stls/jefferson_bragg_inpatient.stl
# 81 ./data/stls/jess_black_far_cry.stl
# 81 ./data/stls/jess_black_far_cry.stl
# 82 ./data/stls/jessica_until_dawn.stl
# 82 ./data/stls/jessica_until_dawn.stl
# 83 ./data/stls/jherii_gallo_dead_rising.stl
# 83 ./data/stls/jherii_gallo_dead_rising.stl
# 84 ./data/stls/jodie_two_souls.stl
# 84 ./data/stls/jodie_two_souls.stl
# 85 ./data/stls/joel_last_of_us.stl
# 85 ./data/stls/joel_last_of_us.stl
# 86 ./data/stls/joey_hudson_far_cry.stl
# 86 ./data/stls/joey_hudson_far_cry.stl
# 87 ./data/stls/john_hemlock_dead_rising.stl
# 87 ./data/stls/john_hemlock_dead_rising.stl
# 88 ./data/stls/john_seed_far_cry.stl
# 88 ./data/stls/john_seed_far_cry.stl
# 89 ./data/stls/jonah_maiava_tomb_raider.stl
# 89 ./data/stls/jonah_maiava_tomb_raider.stl
# 90 ./data/stls/joseph_seed_far_cry.stl
# 90 ./data/stls/joseph_seed_far_cry.stl
# 91 ./data/stls/juli_kidman_evil_within.stl
# 91 ./data/stls/juli_kidman_evil_within.stl
# 92 ./data/stls/jyn_erso_battlefront_2.stl
# 92 ./data/stls/jyn_erso_battlefront_2.stl
# 93 ./data/stls/kara_detroit.stl
# 93 ./data/stls/kara_detroit.stl
# 94 ./data/stls/kendo_gunshopowner_resident_evil.stl
# 94 ./data/stls/kendo_gunshopowner_resident_evil.stl
# 95 ./data/stls/kirsten_mom_two_souls.stl
# 95 ./data/stls/kirsten_mom_two_souls.stl
# 96 ./data/stls/kirsten_two_souls.stl
# 96 ./data/stls/kirsten_two_souls.stl
# 97 ./data/stls/lady_dmc.stl
# 97 ./data/stls/lady_dmc.stl
# 98 ./data/stls/lara_croft_child_tomb_raider.stl
# 98 ./data/stls/lara_croft_child_tomb_raider.stl
# 99 ./data/stls/lara_croft_tomb_raider.stl
# 99 ./data/stls/lara_croft_tomb_raider.stl
# 100 ./data/stls/laura_dawkins_two_souls.stl
# 100 ./data/stls/laura_dawkins_two_souls.stl
# 101 ./data/stls/lauren_winter_heavy_rain.stl
# 101 ./data/stls/lauren_winter_heavy_rain.stl
# 102 ./data/stls/ledolas_final_fantasy.stl
# 102 ./data/stls/ledolas_final_fantasy.stl
# 103 ./data/stls/leia_battlefront_2.stl
# 103 ./data/stls/leia_battlefront_2.stl
# 104 ./data/stls/leon_resident_evil.stl
# 104 ./data/stls/leon_resident_evil.stl
# 105 ./data/stls/lily_castellanos_evil_within.stl
# 105 ./data/stls/lily_castellanos_evil_within.stl
# 106 ./data/stls/lincoln_mafia_3.stl
# 106 ./data/stls/lincoln_mafia_3.stl
# 107 ./data/stls/luke_skywalker_battlefront_2.stl
# 107 ./data/stls/luke_skywalker_battlefront_2.stl
# 108 ./data/stls/madame_flavigny_assassins_creed.stl
# 108 ./data/stls/madame_flavigny_assassins_creed.stl
# 109 ./data/stls/madison_paige_heavy_rain.stl
# 109 ./data/stls/madison_paige_heavy_rain.stl
# 110 ./data/stls/mand_head_centered.stl
# 110 ./data/stls/mand_head_centered.stl
# 111 ./data/stls/markus_detroit.stl
# 111 ./data/stls/markus_detroit.stl
# 112 ./data/stls/markus_gears_of_war.stl
# 112 ./data/stls/markus_gears_of_war.stl
# 113 ./data/stls/marta_martin_evil_within.stl
# 113 ./data/stls/marta_martin_evil_within.stl
# 114 ./data/stls/matt_two_souls.stl
# 114 ./data/stls/matt_two_souls.stl
# 115 ./data/stls/matt_until_dawn.stl
# 115 ./data/stls/matt_until_dawn.stl
# 116 ./data/stls/maya_overkill_walking_dead.stl
# 116 ./data/stls/maya_overkill_walking_dead.stl
# 117 ./data/stls/medusa_ascendant_one.stl
# 117 ./data/stls/medusa_ascendant_one.stl
# 118 ./data/stls/melanie_lemay_assassins_creed.stl
# 118 ./data/stls/melanie_lemay_assassins_creed.stl
# 119 ./data/stls/mike_until_dawn.stl
# 119 ./data/stls/mike_until_dawn.stl
# 120 ./data/stls/morrison_dmc.stl
# 120 ./data/stls/morrison_dmc.stl
# 121 ./data/stls/myra_hanson_evil_within.stl
# 121 ./data/stls/myra_hanson_evil_within.stl
# 122 ./data/stls/mysterious_figure_order_1886.stl
# 122 ./data/stls/mysterious_figure_order_1886.stl
# 123 ./data/stls/nero_dmc.stl
# 123 ./data/stls/nero_dmc.stl
# 124 ./data/stls/nick_rye_far_cry.stl
# 124 ./data/stls/nick_rye_far_cry.stl
# 125 ./data/stls/nico_dmc.stl
# 125 ./data/stls/nico_dmc.stl
# 126 ./data/stls/nike_ascendant_one.stl
# 126 ./data/stls/nike_ascendant_one.stl
# 127 ./data/stls/nikola_tesla_order_1886.stl
# 127 ./data/stls/nikola_tesla_order_1886.stl
# 128 ./data/stls/norman_jayden_heavy_rain.stl
# 128 ./data/stls/norman_jayden_heavy_rain.stl
# 129 ./data/stls/north_detroit.stl
# 129 ./data/stls/north_detroit.stl
# 130 ./data/stls/nyx_ascendant_one.stl
# 130 ./data/stls/nyx_ascendant_one.stl
# 131 ./data/stls/obi_wan_kenobi_battlefront_2.stl
# 131 ./data/stls/obi_wan_kenobi_battlefront_2.stl
# 132 ./data/stls/paco_mendez_heavy_rain.stl
# 132 ./data/stls/paco_mendez_heavy_rain.stl
# 133 ./data/stls/pandora_ascendant_one.stl
# 133 ./data/stls/pandora_ascendant_one.stl
# 134 ./data/stls/paul_two_souls.stl
# 134 ./data/stls/paul_two_souls.stl
# 135 ./data/stls/pearl_attaway_assassins_creed.stl
# 135 ./data/stls/pearl_attaway_assassins_creed.stl
# 136 ./data/stls/persephone_ascendant_one.stl
# 136 ./data/stls/persephone_ascendant_one.stl
# 137 ./data/stls/peter_venkman_ghostbusters.stl
# 137 ./data/stls/peter_venkman_ghostbusters.stl
# 138 ./data/stls/poseidon_ascendant_one.stl
# 138 ./data/stls/poseidon_ascendant_one.stl
# 139 ./data/stls/ravus_nox_fleuret_final_fantasy.stl
# 139 ./data/stls/ravus_nox_fleuret_final_fantasy.stl
# 140 ./data/stls/ray_stantz_ghostbusters.stl
# 140 ./data/stls/ray_stantz_ghostbusters.stl
# 141 ./data/stls/rebecca_crane_assassins_creed.stl
# 141 ./data/stls/rebecca_crane_assassins_creed.stl
# 142 ./data/stls/regis_lucis_caelum_suit_final_fantasy.stl
# 142 ./data/stls/regis_lucis_caelum_suit_final_fantasy.stl
# 143 ./data/stls/reina_overkill_walking_dead.stl
# 143 ./data/stls/reina_overkill_walking_dead.stl
# 144 ./data/stls/rey_battlefront_2.stl
# 144 ./data/stls/rey_battlefront_2.stl
# 145 ./data/stls/reyna_gears_of_war.stl
# 145 ./data/stls/reyna_gears_of_war.stl
# 146 ./data/stls/richard_croft_tomb_raider.stl
# 146 ./data/stls/richard_croft_tomb_raider.stl
# 147 ./data/stls/rookie_ghostbusters.stl
# 147 ./data/stls/rookie_ghostbusters.stl
# 148 ./data/stls/rost_horizon_zero_dawn.stl
# 148 ./data/stls/rost_horizon_zero_dawn.stl
# 149 ./data/stls/roxie_mafia_3.stl
# 149 ./data/stls/roxie_mafia_3.stl
# 150 ./data/stls/ruben_victoriano_evil_within.stl
# 150 ./data/stls/ruben_victoriano_evil_within.stl
# 151 ./data/stls/sam_last_of_us.stl
# 151 ./data/stls/sam_last_of_us.stl
# 152 ./data/stls/sam_until_dawn.stl
# 152 ./data/stls/sam_until_dawn.stl
# 153 ./data/stls/sebastian_castellanos_evil_within.stl
# 153 ./data/stls/sebastian_castellanos_evil_within.stl
# 154 ./data/stls/shang_tsung_mortal_combat.stl
# 154 ./data/stls/shang_tsung_mortal_combat.stl
# 155 ./data/stls/shaun_hastings_assassins_creed.stl
# 155 ./data/stls/shaun_hastings_assassins_creed.stl
# 156 ./data/stls/sherman_two_souls.stl
# 156 ./data/stls/sherman_two_souls.stl
# 157 ./data/stls/shimasani_two_souls.stl
# 157 ./data/stls/shimasani_two_souls.stl
# 158 ./data/stls/shinobu_no_more_heroes.stl
# 158 ./data/stls/shinobu_no_more_heroes.stl
# 159 ./data/stls/sophie_trenet_assassins_creed.stl
# 159 ./data/stls/sophie_trenet_assassins_creed.stl
# 160 ./data/stls/steven_two_souls.stl
# 160 ./data/stls/steven_two_souls.stl
# 161 ./data/stls/summer_prescott_gears_of_war.stl
# 161 ./data/stls/summer_prescott_gears_of_war.stl
# 162 ./data/stls/supergirl_injustice_2.stl
# 162 ./data/stls/supergirl_injustice_2.stl
# 163 ./data/stls/talcott_hester_final_fantasy.stl
# 163 ./data/stls/talcott_hester_final_fantasy.stl
# 164 ./data/stls/tatiana_gutierrez_evil_within.stl
# 164 ./data/stls/tatiana_gutierrez_evil_within.stl
# 165 ./data/stls/theodore_lagerfeld_dead_rising.stl
# 165 ./data/stls/theodore_lagerfeld_dead_rising.stl
# 166 ./data/stls/theodore_wallace_evil_within.stl
# 166 ./data/stls/theodore_wallace_evil_within.stl
# 167 ./data/stls/todd_detroit.stl
# 167 ./data/stls/todd_detroit.stl
# 168 ./data/stls/traci_detroit.stl
# 168 ./data/stls/traci_detroit.stl
# 169 ./data/stls/travis_no_more_heroes.stl
# 169 ./data/stls/travis_no_more_heroes.stl
# 170 ./data/stls/trish_dmc.stl
# 170 ./data/stls/trish_dmc.stl
# 171 ./data/stls/v_dmc.stl
# 171 ./data/stls/v_dmc.stl
# 172 ./data/stls/vanasha_horizon_zero_dawn.stl
# 172 ./data/stls/vanasha_horizon_zero_dawn.stl
# 173 ./data/stls/vergil_dmc.stl
# 173 ./data/stls/vergil_dmc.stl
# 174 ./data/stls/verstael_besithia_final_fantasy.stl
# 174 ./data/stls/verstael_besithia_final_fantasy.stl
# 175 ./data/stls/vicky_chu_dead_rising.stl
# 175 ./data/stls/vicky_chu_dead_rising.stl
# 176 ./data/stls/victoria_laboucher_inpatient.stl
# 176 ./data/stls/victoria_laboucher_inpatient.stl
# 177 ./data/stls/violet_assassins_creed.stl
# 177 ./data/stls/violet_assassins_creed.stl
# 178 ./data/stls/vixen_injustice_2.stl
# 178 ./data/stls/vixen_injustice_2.stl
# 179 ./data/stls/weskham_armaugh_final_fantasy.stl
# 179 ./data/stls/weskham_armaugh_final_fantasy.stl
# 180 ./data/stls/winston_zeddemore_ghostbusters.stl
# 180 ./data/stls/winston_zeddemore_ghostbusters.stl
# 181 ./data/stls/young_noctis_final_fantasy.stl
# 181 ./data/stls/young_noctis_final_fantasy.stl
# 182 ./data/stls/yukiko_hoffman_evil_within.stl
# 182 ./data/stls/yukiko_hoffman_evil_within.stl
# 183 ./data/stls/zoe_detroit.stl
# 183 ./data/stls/zoe_detroit.stl

# %%
len(paths[100])
# Out:
# 166

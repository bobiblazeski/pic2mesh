# %%
#!/usr/bin/env python3
# Copyright (c) Facebook, Inc. and its affiliates. All rights reserved.
"""
This example demonstrates scene optimization with the PyTorch3D
pulsar interface. For this, a reference image has been pre-generated
(you can find it at `../../tests/pulsar/reference/examples_TestRenderer_test_smallopt.png`).
The scene is initialized with random spheres. Gradient-based
optimization is used to converge towards a faithful
scene representation.
"""
import logging
import math

import cv2
import imageio
import numpy as np
import torch

# Import `look_at_view_transform` as needed in the suggestion later in the
# example.
from pytorch3d.renderer.cameras import PerspectiveCameras  # , look_at_view_transform
from pytorch3d.renderer.points import (
    PointsRasterizationSettings,
    PointsRasterizer,
    PulsarPointsRenderer,
)
from pytorch3d.structures.pointclouds import Pointclouds
from torch import nn, optim

# %%
LOGGER = logging.getLogger(__name__)
N_POINTS = 10_000
WIDTH = 1_000
HEIGHT = 1_000
DEVICE = torch.device("cuda")

class SceneModel(nn.Module):
    """
    A simple scene model to demonstrate use of pulsar in PyTorch modules.

    The scene model is parameterized with sphere locations (vert_pos),
    channel content (vert_col), radiuses (vert_rad), camera position (cam_pos),
    camera rotation (cam_rot) and sensor focal length and width (cam_sensor).

    The forward method of the model renders this scene description. Any
    of these parameters could instead be passed as inputs to the forward
    method and come from a different model.
    """

    def __init__(self):
        super(SceneModel, self).__init__()
        self.gamma = 1.0
        # Points.
        torch.manual_seed(1)
        vert_pos = torch.rand(N_POINTS, 3, dtype=torch.float32, device=DEVICE) * 10.0
        vert_pos[:, 2] += 25.0
        vert_pos[:, :2] -= 5.0
        self.register_parameter("vert_pos", nn.Parameter(vert_pos, requires_grad=True))
        self.register_parameter(
            "vert_col",
            nn.Parameter(
                torch.ones(N_POINTS, 3, dtype=torch.float32, device=DEVICE) * 0.5,
                requires_grad=True,
            ),
        )
        self.register_parameter(
            "vert_rad",
            nn.Parameter(
                torch.ones(N_POINTS, dtype=torch.float32) * 0.3, requires_grad=True
            ),
        )
        self.register_buffer(
            "cam_params",
            torch.tensor(
                [0.0, 0.0, 0.0, 0.0, math.pi, 0.0, 5.0, 2.0], dtype=torch.float32
            ),
        )
        self.cameras = PerspectiveCameras(
            # The focal length must be double the size for PyTorch3D because of the NDC
            # coordinates spanning a range of two - and they must be normalized by the
            # sensor width (see the pulsar example). This means we need here
            # 5.0 * 2.0 / 2.0 to get the equivalent results as in pulsar.
            focal_length=5.0,
            R=torch.eye(3, dtype=torch.float32, device=DEVICE)[None, ...],
            T=torch.zeros((1, 3), dtype=torch.float32, device=DEVICE),
            image_size=((WIDTH, HEIGHT),),
            device=DEVICE,
        )
        raster_settings = PointsRasterizationSettings(
            image_size=(WIDTH, HEIGHT),
            radius=self.vert_rad,
        )
        rasterizer = PointsRasterizer(
            cameras=self.cameras, raster_settings=raster_settings
        )
        self.renderer = PulsarPointsRenderer(rasterizer=rasterizer, n_track=32)

    def forward(self):
        # The Pointclouds object creates copies of it's arguments - that's why
        # we have to create a new object in every forward step.
        pcl = Pointclouds(
            points=self.vert_pos[None, ...], features=self.vert_col[None, ...]
        )
        return self.renderer(
            pcl,
            gamma=(self.gamma,),
            zfar=(45.0,),
            znear=(1.0,),
            radius_world=True,
            bg_col=torch.ones((3,), dtype=torch.float32, device=DEVICE),
        )[0]


def cli():
    """
    Scene optimization example using pulsar and the unified PyTorch3D interface.
    """
    LOGGER.info("Loading reference...")
    # Load reference.
    ref = (
        torch.from_numpy(
            imageio.imread(
                "./data/examples_TestRenderer_test_smallopt.png"
            )[:, ::-1, :].copy()
        ).to(torch.float32)
        / 255.0
    ).to(DEVICE)
    # Set up model.
    model = SceneModel().to(DEVICE)
    # Optimizer.
    optimizer = optim.SGD(
        [
            {"params": [model.vert_col], "lr": 1e0},
            {"params": [model.vert_rad], "lr": 5e-3},
            {"params": [model.vert_pos], "lr": 1e-2},
        ]
    )
    LOGGER.info("Optimizing...")
    # Optimize.
    for i in range(500):
        optimizer.zero_grad()
        result = model()
        # Visualize.
        result_im = (result.cpu().detach().numpy() * 255).astype(np.uint8)
        cv2.imshow("opt", result_im[:, :, ::-1])
        overlay_img = np.ascontiguousarray(
            ((result * 0.5 + ref * 0.5).cpu().detach().numpy() * 255).astype(np.uint8)[
                :, :, ::-1
            ]
        )
        overlay_img = cv2.putText(
            overlay_img,
            "Step %d" % (i),
            (10, 40),
            cv2.FONT_HERSHEY_SIMPLEX,
            1,
            (0, 0, 0),
            2,
            cv2.LINE_AA,
            False,
        )
        cv2.imshow("overlay", overlay_img)
        cv2.waitKey(1)
        # Update.
        loss = ((result - ref) ** 2).sum()
        LOGGER.info("loss %d: %f", i, loss.item())
        loss.backward()
        optimizer.step()
        # Cleanup.
        with torch.no_grad():
            model.vert_col.data = torch.clamp(model.vert_col.data, 0.0, 1.0)
            # Remove points.
            model.vert_pos.data[model.vert_rad < 0.001, :] = -1000.0
            model.vert_rad.data[model.vert_rad < 0.001] = 0.0001
            vd = (
                (model.vert_col - torch.ones(3, dtype=torch.float32).to(DEVICE))
                .abs()
                .sum(dim=1)
            )
            model.vert_pos.data[vd <= 0.2] = -1000.0
    LOGGER.info("Done.")

# %%
logging.basicConfig(level=logging.INFO)
cli()
# Out:
# INFO:__main__:Loading reference...
# INFO:__main__:Optimizing...
# INFO:__main__:loss 0: 488075.500000
# INFO:__main__:loss 1: 409452.125000
# INFO:__main__:loss 2: 346267.125000
# INFO:__main__:loss 3: 294852.500000
# INFO:__main__:loss 4: 252508.687500
# INFO:__main__:loss 5: 217286.156250
# INFO:__main__:loss 6: 187805.812500
# INFO:__main__:loss 7: 162923.531250
# INFO:__main__:loss 8: 141823.625000
# INFO:__main__:loss 9: 123827.796875
# INFO:__main__:loss 10: 108440.523438
# INFO:__main__:loss 11: 95148.750000
# INFO:__main__:loss 12: 83743.515625
# INFO:__main__:loss 13: 73848.468750
# INFO:__main__:loss 14: 65293.097656
# INFO:__main__:loss 15: 57912.062500
# INFO:__main__:loss 16: 51409.648438
# INFO:__main__:loss 17: 45727.000000
# INFO:__main__:loss 18: 40828.148438
# INFO:__main__:loss 19: 36610.023438
# INFO:__main__:loss 20: 32953.355469
# INFO:__main__:loss 21: 29807.783203
# INFO:__main__:loss 22: 27107.919922
# INFO:__main__:loss 23: 24652.171875
# INFO:__main__:loss 24: 22547.078125
# INFO:__main__:loss 25: 20667.951172
# INFO:__main__:loss 26: 19078.906250
# INFO:__main__:loss 27: 17530.507812
# INFO:__main__:loss 28: 16121.380859
# INFO:__main__:loss 29: 14846.113281
# INFO:__main__:loss 30: 13706.337891
# INFO:__main__:loss 31: 12661.119141
# INFO:__main__:loss 32: 11699.795898
# INFO:__main__:loss 33: 10785.504883
# INFO:__main__:loss 34: 9984.021484
# INFO:__main__:loss 35: 9248.880859
# INFO:__main__:loss 36: 8662.144531
# INFO:__main__:loss 37: 8212.974609
# INFO:__main__:loss 38: 7852.002930
# INFO:__main__:loss 39: 7538.187988
# INFO:__main__:loss 40: 7258.211914
# INFO:__main__:loss 41: 6977.083008
# INFO:__main__:loss 42: 6698.519531
# INFO:__main__:loss 43: 6506.989258
# INFO:__main__:loss 44: 6266.093750
# INFO:__main__:loss 45: 6116.650391
# INFO:__main__:loss 46: 5984.810059
# INFO:__main__:loss 47: 5842.194824
# INFO:__main__:loss 48: 5683.903320
# INFO:__main__:loss 49: 5487.316406
# INFO:__main__:loss 50: 5309.457520
# INFO:__main__:loss 51: 5208.886719
# INFO:__main__:loss 52: 5058.271484
# INFO:__main__:loss 53: 4893.345703
# INFO:__main__:loss 54: 4776.573242
# INFO:__main__:loss 55: 4630.953613
# INFO:__main__:loss 56: 4490.806152
# INFO:__main__:loss 57: 4377.938965
# INFO:__main__:loss 58: 4263.958008
# INFO:__main__:loss 59: 4175.167480
# INFO:__main__:loss 60: 4068.102295
# INFO:__main__:loss 61: 3981.204346
# INFO:__main__:loss 62: 3879.893555
# INFO:__main__:loss 63: 3770.058105
# INFO:__main__:loss 64: 3685.631348
# INFO:__main__:loss 65: 3617.580566
# INFO:__main__:loss 66: 3526.470459
# INFO:__main__:loss 67: 3449.834961
# INFO:__main__:loss 68: 3363.411621
# INFO:__main__:loss 69: 3291.729004
# INFO:__main__:loss 70: 3224.446777
# INFO:__main__:loss 71: 3143.622559
# INFO:__main__:loss 72: 3089.767578
# INFO:__main__:loss 73: 3027.569824
# INFO:__main__:loss 74: 2946.801270
# INFO:__main__:loss 75: 2883.962891
# INFO:__main__:loss 76: 2825.338379
# INFO:__main__:loss 77: 2759.656738
# INFO:__main__:loss 78: 2700.635742
# INFO:__main__:loss 79: 2643.099609
# INFO:__main__:loss 80: 2591.583984
# INFO:__main__:loss 81: 2536.034424
# INFO:__main__:loss 82: 2490.108643
# INFO:__main__:loss 83: 2437.340332
# INFO:__main__:loss 84: 2391.930420
# INFO:__main__:loss 85: 2340.923340
# INFO:__main__:loss 86: 2304.204834
# INFO:__main__:loss 87: 2244.450928
# INFO:__main__:loss 88: 2199.608887
# INFO:__main__:loss 89: 2157.581543
# INFO:__main__:loss 90: 2124.647949
# INFO:__main__:loss 91: 2071.310547
# INFO:__main__:loss 92: 2034.255737
# INFO:__main__:loss 93: 1998.184814
# INFO:__main__:loss 94: 1959.222046
# INFO:__main__:loss 95: 1921.100586
# INFO:__main__:loss 96: 1888.116333
# INFO:__main__:loss 97: 1858.661621
# INFO:__main__:loss 98: 1831.515137
# INFO:__main__:loss 99: 1804.105957
# INFO:__main__:loss 100: 1775.966309
# INFO:__main__:loss 101: 1747.117920
# INFO:__main__:loss 102: 1722.549438
# INFO:__main__:loss 103: 1701.263916
# INFO:__main__:loss 104: 1678.682617
# INFO:__main__:loss 105: 1657.183105
# INFO:__main__:loss 106: 1635.870117
# INFO:__main__:loss 107: 1611.157715
# INFO:__main__:loss 108: 1593.108032
# INFO:__main__:loss 109: 1568.004395
# INFO:__main__:loss 110: 1549.156616
# INFO:__main__:loss 111: 1530.021484
# INFO:__main__:loss 112: 1501.245605
# INFO:__main__:loss 113: 1485.757202
# INFO:__main__:loss 114: 1472.773438
# INFO:__main__:loss 115: 1451.096680
# INFO:__main__:loss 116: 1430.118164
# INFO:__main__:loss 117: 1411.625000
# INFO:__main__:loss 118: 1394.220215
# INFO:__main__:loss 119: 1372.584473
# INFO:__main__:loss 120: 1357.693359
# INFO:__main__:loss 121: 1340.522095
# INFO:__main__:loss 122: 1326.462280
# INFO:__main__:loss 123: 1313.524170
# INFO:__main__:loss 124: 1304.337769
# INFO:__main__:loss 125: 1291.502930
# INFO:__main__:loss 126: 1280.084717
# INFO:__main__:loss 127: 1268.356934
# INFO:__main__:loss 128: 1257.742920
# INFO:__main__:loss 129: 1247.315918
# INFO:__main__:loss 130: 1236.285400
# INFO:__main__:loss 131: 1224.779419
# INFO:__main__:loss 132: 1211.858643
# INFO:__main__:loss 133: 1205.732910
# INFO:__main__:loss 134: 1191.687012
# INFO:__main__:loss 135: 1179.459229
# INFO:__main__:loss 136: 1167.844604
# INFO:__main__:loss 137: 1157.804932
# INFO:__main__:loss 138: 1147.832275
# INFO:__main__:loss 139: 1138.111938
# INFO:__main__:loss 140: 1129.327393
# INFO:__main__:loss 141: 1121.810181
# INFO:__main__:loss 142: 1112.445801
# INFO:__main__:loss 143: 1104.181519
# INFO:__main__:loss 144: 1095.297363
# INFO:__main__:loss 145: 1089.075806
# INFO:__main__:loss 146: 1082.807617
# INFO:__main__:loss 147: 1076.354370
# INFO:__main__:loss 148: 1068.452148
# INFO:__main__:loss 149: 1061.440918
# INFO:__main__:loss 150: 1054.429443
# INFO:__main__:loss 151: 1048.647949
# INFO:__main__:loss 152: 1041.896484
# INFO:__main__:loss 153: 1032.664062
# INFO:__main__:loss 154: 1027.625854
# INFO:__main__:loss 155: 1007.090820
# INFO:__main__:loss 156: 999.202637
# INFO:__main__:loss 157: 988.499695
# INFO:__main__:loss 158: 981.152588
# INFO:__main__:loss 159: 973.775391
# INFO:__main__:loss 160: 967.869568
# INFO:__main__:loss 161: 961.460388
# INFO:__main__:loss 162: 956.515137
# INFO:__main__:loss 163: 949.154297
# INFO:__main__:loss 164: 943.985474
# INFO:__main__:loss 165: 935.908386
# INFO:__main__:loss 166: 931.185242
# INFO:__main__:loss 167: 926.253540
# INFO:__main__:loss 168: 920.141479
# INFO:__main__:loss 169: 915.124939
# INFO:__main__:loss 170: 909.731689
# INFO:__main__:loss 171: 908.380493
# INFO:__main__:loss 172: 903.521851
# INFO:__main__:loss 173: 897.605835
# INFO:__main__:loss 174: 892.860596
# INFO:__main__:loss 175: 887.834839
# INFO:__main__:loss 176: 883.675049
# INFO:__main__:loss 177: 878.049133
# INFO:__main__:loss 178: 872.825439
# INFO:__main__:loss 179: 868.668335
# INFO:__main__:loss 180: 863.831299
# INFO:__main__:loss 181: 860.009766
# INFO:__main__:loss 182: 859.960266
# INFO:__main__:loss 183: 854.463379
# INFO:__main__:loss 184: 849.968018
# INFO:__main__:loss 185: 844.704102
# INFO:__main__:loss 186: 839.628540
# INFO:__main__:loss 187: 835.532593
# INFO:__main__:loss 188: 829.893311
# INFO:__main__:loss 189: 825.806641
# INFO:__main__:loss 190: 822.306152
# INFO:__main__:loss 191: 817.361572
# INFO:__main__:loss 192: 814.600891
# INFO:__main__:loss 193: 811.100586
# INFO:__main__:loss 194: 806.390320
# INFO:__main__:loss 195: 803.683899
# INFO:__main__:loss 196: 801.028687
# INFO:__main__:loss 197: 796.149414
# INFO:__main__:loss 198: 791.254150
# INFO:__main__:loss 199: 788.338684
# INFO:__main__:loss 200: 783.021851
# INFO:__main__:loss 201: 779.752075
# INFO:__main__:loss 202: 776.005859
# INFO:__main__:loss 203: 772.559448
# INFO:__main__:loss 204: 767.528198
# INFO:__main__:loss 205: 764.271545
# INFO:__main__:loss 206: 760.686279
# INFO:__main__:loss 207: 757.096313
# INFO:__main__:loss 208: 755.007690
# INFO:__main__:loss 209: 751.708374
# INFO:__main__:loss 210: 748.843323
# INFO:__main__:loss 211: 745.282715
# INFO:__main__:loss 212: 741.440918
# INFO:__main__:loss 213: 740.087646
# INFO:__main__:loss 214: 736.538818
# INFO:__main__:loss 215: 733.401855
# INFO:__main__:loss 216: 729.941284
# INFO:__main__:loss 217: 727.494141
# INFO:__main__:loss 218: 724.275635
# INFO:__main__:loss 219: 721.481079
# INFO:__main__:loss 220: 718.250732
# INFO:__main__:loss 221: 715.565063
# INFO:__main__:loss 222: 713.470215
# INFO:__main__:loss 223: 710.388672
# INFO:__main__:loss 224: 707.389709
# INFO:__main__:loss 225: 703.938354
# INFO:__main__:loss 226: 701.562378
# INFO:__main__:loss 227: 698.496887
# INFO:__main__:loss 228: 696.301086
# INFO:__main__:loss 229: 693.052917
# INFO:__main__:loss 230: 690.683289
# INFO:__main__:loss 231: 687.790771
# INFO:__main__:loss 232: 684.717773
# INFO:__main__:loss 233: 681.991821
# INFO:__main__:loss 234: 679.000488
# INFO:__main__:loss 235: 676.400024
# INFO:__main__:loss 236: 674.494324
# INFO:__main__:loss 237: 670.569580
# INFO:__main__:loss 238: 667.609253
# INFO:__main__:loss 239: 665.298584
# INFO:__main__:loss 240: 662.967529
# INFO:__main__:loss 241: 659.449463
# INFO:__main__:loss 242: 657.318970
# INFO:__main__:loss 243: 653.644287
# INFO:__main__:loss 244: 651.926392
# INFO:__main__:loss 245: 648.921570
# INFO:__main__:loss 246: 646.026672
# INFO:__main__:loss 247: 636.805054
# INFO:__main__:loss 248: 634.394531
# INFO:__main__:loss 249: 630.962341
# INFO:__main__:loss 250: 628.255371
# INFO:__main__:loss 251: 626.324402
# INFO:__main__:loss 252: 622.607178
# INFO:__main__:loss 253: 619.860779
# INFO:__main__:loss 254: 617.742981
# INFO:__main__:loss 255: 614.695618
# INFO:__main__:loss 256: 612.342529
# INFO:__main__:loss 257: 611.322754
# INFO:__main__:loss 258: 608.414795
# INFO:__main__:loss 259: 605.161865
# INFO:__main__:loss 260: 602.207214
# INFO:__main__:loss 261: 599.476685
# INFO:__main__:loss 262: 596.989868
# INFO:__main__:loss 263: 594.957153
# INFO:__main__:loss 264: 592.710205
# INFO:__main__:loss 265: 589.873535
# INFO:__main__:loss 266: 588.397949
# INFO:__main__:loss 267: 585.933350
# INFO:__main__:loss 268: 583.964966
# INFO:__main__:loss 269: 581.346191
# INFO:__main__:loss 270: 578.429443
# INFO:__main__:loss 271: 577.191833
# INFO:__main__:loss 272: 574.979553
# INFO:__main__:loss 273: 572.977234
# INFO:__main__:loss 274: 571.744019
# INFO:__main__:loss 275: 569.343689
# INFO:__main__:loss 276: 567.306030
# INFO:__main__:loss 277: 565.659302
# INFO:__main__:loss 278: 563.108643
# INFO:__main__:loss 279: 561.798523
# INFO:__main__:loss 280: 560.115540
# INFO:__main__:loss 281: 557.668030
# INFO:__main__:loss 282: 556.184021
# INFO:__main__:loss 283: 554.704529
# INFO:__main__:loss 284: 552.626709
# INFO:__main__:loss 285: 550.550171
# INFO:__main__:loss 286: 548.412842
# INFO:__main__:loss 287: 547.498779
# INFO:__main__:loss 288: 545.112793
# INFO:__main__:loss 289: 544.030334
# INFO:__main__:loss 290: 542.386353
# INFO:__main__:loss 291: 540.448792
# INFO:__main__:loss 292: 539.730652
# INFO:__main__:loss 293: 537.491943
# INFO:__main__:loss 294: 536.043091
# INFO:__main__:loss 295: 534.931335
# INFO:__main__:loss 296: 533.239990
# INFO:__main__:loss 297: 532.224121
# INFO:__main__:loss 298: 532.475647
# INFO:__main__:loss 299: 530.136963
# INFO:__main__:loss 300: 529.907959
# INFO:__main__:loss 301: 528.289551
# INFO:__main__:loss 302: 526.906006
# INFO:__main__:loss 303: 525.148193
# INFO:__main__:loss 304: 523.993164
# INFO:__main__:loss 305: 523.154480
# INFO:__main__:loss 306: 522.349670
# INFO:__main__:loss 307: 521.614807
# INFO:__main__:loss 308: 519.980103
# INFO:__main__:loss 309: 518.489441
# INFO:__main__:loss 310: 517.585571
# INFO:__main__:loss 311: 520.079651
# INFO:__main__:loss 312: 518.117676
# INFO:__main__:loss 313: 516.737305
# INFO:__main__:loss 314: 515.302673
# INFO:__main__:loss 315: 514.359619
# INFO:__main__:loss 316: 513.940125
# INFO:__main__:loss 317: 512.866821
# INFO:__main__:loss 318: 510.666931
# INFO:__main__:loss 319: 510.428894
# INFO:__main__:loss 320: 509.167053
# INFO:__main__:loss 321: 507.676208
# INFO:__main__:loss 322: 507.451691
# INFO:__main__:loss 323: 506.175476
# INFO:__main__:loss 324: 505.379059
# INFO:__main__:loss 325: 504.340210
# INFO:__main__:loss 326: 503.342957
# INFO:__main__:loss 327: 502.509888
# INFO:__main__:loss 328: 501.808136
# INFO:__main__:loss 329: 500.628387
# INFO:__main__:loss 330: 499.913086
# INFO:__main__:loss 331: 499.134949
# INFO:__main__:loss 332: 498.182037
# INFO:__main__:loss 333: 497.535767
# INFO:__main__:loss 334: 496.706421
# INFO:__main__:loss 335: 495.248352
# INFO:__main__:loss 336: 494.401611
# INFO:__main__:loss 337: 493.955414
# INFO:__main__:loss 338: 493.570618
# INFO:__main__:loss 339: 492.179504
# INFO:__main__:loss 340: 491.812439
# INFO:__main__:loss 341: 490.411194
# INFO:__main__:loss 342: 490.102234
# INFO:__main__:loss 343: 490.349457
# INFO:__main__:loss 344: 490.810730
# INFO:__main__:loss 345: 489.365906
# INFO:__main__:loss 346: 488.644104
# INFO:__main__:loss 347: 487.440918
# INFO:__main__:loss 348: 487.110718
# INFO:__main__:loss 349: 485.925293
# INFO:__main__:loss 350: 485.224915
# INFO:__main__:loss 351: 484.156128
# INFO:__main__:loss 352: 483.830505
# INFO:__main__:loss 353: 486.881775
# INFO:__main__:loss 354: 485.377075
# INFO:__main__:loss 355: 484.539337
# INFO:__main__:loss 356: 482.637512
# INFO:__main__:loss 357: 482.437653
# INFO:__main__:loss 358: 481.142395
# INFO:__main__:loss 359: 479.603485
# INFO:__main__:loss 360: 479.012756
# INFO:__main__:loss 361: 477.772217
# INFO:__main__:loss 362: 477.199402
# INFO:__main__:loss 363: 476.410431
# INFO:__main__:loss 364: 474.718567
# INFO:__main__:loss 365: 474.410706
# INFO:__main__:loss 366: 472.880859
# INFO:__main__:loss 367: 472.879578
# INFO:__main__:loss 368: 472.206116
# INFO:__main__:loss 369: 471.046814
# INFO:__main__:loss 370: 470.490601
# INFO:__main__:loss 371: 469.571716
# INFO:__main__:loss 372: 468.166992
# INFO:__main__:loss 373: 467.785583
# INFO:__main__:loss 374: 467.504211
# INFO:__main__:loss 375: 466.249664
# INFO:__main__:loss 376: 468.839294
# INFO:__main__:loss 377: 467.699341
# INFO:__main__:loss 378: 466.721100
# INFO:__main__:loss 379: 466.111328
# INFO:__main__:loss 380: 464.300201
# INFO:__main__:loss 381: 463.932068
# INFO:__main__:loss 382: 462.914246
# INFO:__main__:loss 383: 462.299805
# INFO:__main__:loss 384: 460.842926
# INFO:__main__:loss 385: 460.280151
# INFO:__main__:loss 386: 459.947815
# INFO:__main__:loss 387: 459.134705
# INFO:__main__:loss 388: 457.660706
# INFO:__main__:loss 389: 457.249390
# INFO:__main__:loss 390: 456.285339
# INFO:__main__:loss 391: 455.221252
# INFO:__main__:loss 392: 454.737122
# INFO:__main__:loss 393: 454.145203
# INFO:__main__:loss 394: 453.213715
# INFO:__main__:loss 395: 452.225616
# INFO:__main__:loss 396: 451.896179
# INFO:__main__:loss 397: 451.194977
# INFO:__main__:loss 398: 450.304810
# INFO:__main__:loss 399: 449.090576
# INFO:__main__:loss 400: 449.193420
# INFO:__main__:loss 401: 448.329590
# INFO:__main__:loss 402: 447.191467
# INFO:__main__:loss 403: 445.720032
# INFO:__main__:loss 404: 446.174500
# INFO:__main__:loss 405: 446.247803
# INFO:__main__:loss 406: 445.462189
# INFO:__main__:loss 407: 444.909912
# INFO:__main__:loss 408: 442.993713
# INFO:__main__:loss 409: 443.078064
# INFO:__main__:loss 410: 441.060883
# INFO:__main__:loss 411: 440.476501
# INFO:__main__:loss 412: 439.260681
# INFO:__main__:loss 413: 438.667206
# INFO:__main__:loss 414: 437.530884
# INFO:__main__:loss 415: 436.538422
# INFO:__main__:loss 416: 435.150818
# INFO:__main__:loss 417: 434.281586
# INFO:__main__:loss 418: 432.851379
# INFO:__main__:loss 419: 431.546509
# INFO:__main__:loss 420: 430.776306
# INFO:__main__:loss 421: 428.718811
# INFO:__main__:loss 422: 427.827881
# INFO:__main__:loss 423: 426.154358
# INFO:__main__:loss 424: 425.067596
# INFO:__main__:loss 425: 423.898193
# INFO:__main__:loss 426: 422.674652
# INFO:__main__:loss 427: 420.614929
# INFO:__main__:loss 428: 419.487213
# INFO:__main__:loss 429: 417.871643
# INFO:__main__:loss 430: 416.581970
# INFO:__main__:loss 431: 414.905396
# INFO:__main__:loss 432: 413.764374
# INFO:__main__:loss 433: 412.550323
# INFO:__main__:loss 434: 411.141968
# INFO:__main__:loss 435: 410.376892
# INFO:__main__:loss 436: 409.103271
# INFO:__main__:loss 437: 407.468140
# INFO:__main__:loss 438: 406.843506
# INFO:__main__:loss 439: 405.744446
# INFO:__main__:loss 440: 405.944672
# INFO:__main__:loss 441: 404.862793
# INFO:__main__:loss 442: 404.463409
# INFO:__main__:loss 443: 404.053406
# INFO:__main__:loss 444: 403.752045
# INFO:__main__:loss 445: 402.812988
# INFO:__main__:loss 446: 402.574524
# INFO:__main__:loss 447: 402.951477
# INFO:__main__:loss 448: 401.742004
# INFO:__main__:loss 449: 401.590820
# INFO:__main__:loss 450: 401.135925
# INFO:__main__:loss 451: 400.274597
# INFO:__main__:loss 452: 400.614624
# INFO:__main__:loss 453: 400.502136
# INFO:__main__:loss 454: 399.564178
# INFO:__main__:loss 455: 399.530945
# INFO:__main__:loss 456: 399.635956
# INFO:__main__:loss 457: 398.883972
# INFO:__main__:loss 458: 399.325104
# INFO:__main__:loss 459: 398.534851
# INFO:__main__:loss 460: 398.335571
# INFO:__main__:loss 461: 397.425507
# INFO:__main__:loss 462: 397.551025
# INFO:__main__:loss 463: 397.016357
# INFO:__main__:loss 464: 396.649628
# INFO:__main__:loss 465: 396.448456
# INFO:__main__:loss 466: 395.784729
# INFO:__main__:loss 467: 396.074951
# INFO:__main__:loss 468: 395.710205
# INFO:__main__:loss 469: 395.277100
# INFO:__main__:loss 470: 395.182892
# INFO:__main__:loss 471: 394.314941
# INFO:__main__:loss 472: 394.156921
# INFO:__main__:loss 473: 393.524506
# INFO:__main__:loss 474: 394.229065
# INFO:__main__:loss 475: 393.715820
# INFO:__main__:loss 476: 393.433472
# INFO:__main__:loss 477: 392.815613
# INFO:__main__:loss 478: 392.717438
# INFO:__main__:loss 479: 392.244629
# INFO:__main__:loss 480: 391.991943
# INFO:__main__:loss 481: 391.667542
# INFO:__main__:loss 482: 390.612122
# INFO:__main__:loss 483: 391.378540
# INFO:__main__:loss 484: 390.847931
# INFO:__main__:loss 485: 390.661285
# INFO:__main__:loss 486: 390.580261
# INFO:__main__:loss 487: 390.332764
# INFO:__main__:loss 488: 389.850189
# INFO:__main__:loss 489: 389.406219
# INFO:__main__:loss 490: 389.482422
# INFO:__main__:loss 491: 389.108398
# INFO:__main__:loss 492: 388.757416
# INFO:__main__:loss 493: 388.358643
# INFO:__main__:loss 494: 387.830872
# INFO:__main__:loss 495: 387.880280
# INFO:__main__:loss 496: 387.214874
# INFO:__main__:loss 497: 387.383789
# INFO:__main__:loss 498: 387.068787
# INFO:__main__:loss 499: 386.647125
# INFO:__main__:Done.

# %%
import torch

import src.lpips as lpips

# %%
percept = lpips.PerceptualLoss(model='net-lin', net='squeeze', use_gpu=True)
# Out:
# Setting up Perceptual loss...
# Loading model from: /home/bobi/Desktop/pic2mesh/src/lpips/weights/v0.1/squeeze.pth
# ...[net-lin [squeeze]] initialized
# ...Done

# %%
percept(torch.rand(5, 3, 128, 128), torch.rand(5, 3, 128, 128))#.shape
# Out:
# tensor([[[[0.0947]]],
#
#
#         [[[0.0929]]],
#
#
#         [[[0.0956]]],
#
#
#         [[[0.0996]]],
#
#
#         [[[0.0991]]]], device='cuda:0', grad_fn=<AddBackward0>)

# %%
percept(torch.rand(5, 3, 128, 128), torch.rand(5, 3, 128, 128)).shape
# Out:
# torch.Size([5, 1, 1, 1])

# %%
torch.load('./lpips/weights/v0.1/alex.pth')
# Out:
# OrderedDict([('lin0.model.1.weight',
#               tensor([[[[3.7880e-06]],
#
#                        [[1.4750e-01]],
#
#                        [[4.0385e-06]],
#
#                        [[0.0000e+00]],
#
#                        [[1.3018e-05]],
#
#                        [[0.0000e+00]],
#
#                        [[0.0000e+00]],
#
#                        [[0.0000e+00]],
#
#                        [[1.6359e-01]],
#
#                        [[0.0000e+00]],
#
#                        [[0.0000e+00]],
#
#                        [[0.0000e+00]],
#
#                        [[0.0000e+00]],
#
#                        [[0.0000e+00]],
#
#                        [[0.0000e+00]],
#
#                        [[4.6156e-02]],
#
#                        [[0.0000e+00]],
#
#                        [[0.0000e+00]],
#
#                        [[0.0000e+00]],
#
#                        [[1.3645e-01]],
#
#                        [[2.3582e-05]],
#
#                        [[1.7977e-01]],
#
# ...

# %%
from math import (atan2, pi, sqrt)    

from collections import OrderedDict

import os
import numpy as np
import torch
import torch.nn.functional as F

torch.set_printoptions(sci_mode=False)

from src.utilities.polar_traversal import (
    Bridge,
    make_latitudes,
    get_start,
    gather_path,
    cumulative_distances,
)

import src.utilities.polar_traversal as polar_traversal


def get_dist(x, y):
    return sqrt((x-0.5) **2 + (y-0.5) ** 2)

def get_angle(x, y, square_no):
    side = (square_no + 1) * 2
    corr = (side -1) / 2    
    angle = atan2(y -corr, x -corr)
    return angle if angle >= 0 else angle + 2 * pi


def get_sample(pos, normed, path_points, path_normals):    
    i = 1
    while i < len(normed):
        d0, d1 = normed[i-1], normed[i]
        if pos <= d1:
            ratio = (pos - d0) / (d1 - d0) 
            pnt = ratio * path_points[i-1] + (1 - ratio) * path_points[i]
            nrm = ratio * path_normals[i-1] + (1 - ratio) * path_normals[i]
            return pnt, nrm, i
        i += 1
    raise (pos, normed, path)

def single_path_sample(path, layer_no, total_layers):
    cumulative = cumulative_distances(path['points'])
    normed =  cumulative / cumulative[-1]
    pos = (layer_no+1) / (total_layers+1)
    pnt, nrm, _ = get_sample(pos, normed, 
                             path['points'], path['normals'])
    return pnt, nrm

def get_angles_series(n):
    return [x for x in range(0, n*2+1, 2)]


def get_sample(pos, normed, path_points, path_normals):    
    i = 1
    while i < len(normed):
        d0, d1 = normed[i-1], normed[i]
        if pos <= d1:
            ratio = (pos - d0) / (d1 - d0) 
            pnt = ratio * path_points[i-1] + (1 - ratio) * path_points[i]
            nrm = ratio * path_normals[i-1] + (1 - ratio) * path_normals[i]
            return pnt, nrm, i
        i += 1
    raise (pos, normed, path)

def single_path_sample(path, layer_no, total_layers):
    cumulative = cumulative_distances(path['points'])
    normed =  cumulative / cumulative[-1]
    pos = layer_no / total_layers    
    pnt, nrm, _ = get_sample(pos, normed, 
                             path['points'], path['normals'])
    return torch.tensor(pnt).float(), torch.tensor(nrm).float()

def square_indices(n):
    max_idx = 2 * (n+1)
    res = [[0, x] for x in range(max_idx -1, -1, -1)]\
        + [[x, 0] for x in range(1, max_idx)]\
        + [[max_idx -1, x] for x in range(1, max_idx)]\
        + [[x, max_idx -1] for x in range(max_idx -2, 0, -1)]
    return res

def shifted_square_indices(sq_no, square_no):    
    sq_ids =  square_indices(sq_no)
    ost = square_no - sq_no
    return [(i+ost, k+ost) for (i, k) in iter(sq_ids)]

def get_latitudes_angles(n):
    return (torch.arange(0, n) * (2 * pi / n)).tolist()

class Blueprint:
    
    def __init__(self, path, latitudes_num):
        self.path = path
        self.latitudes_num = latitudes_num
        self.bridge = Bridge(path)
        paths_path =  f'./data/paths_{latitudes_num}.pth'        
        if os.path.exists(paths_path):
            self.paths = torch.load(paths_path) 
        else:
            self.paths = self.gather_paths(latitudes_num)
        
    
    def gather_paths(self, latitudes_num=None):
        latitudes_num = latitudes_num or self.latitudes_num  
        latitude_angles = get_latitudes_angles(latitudes_num)        
        latitudes = make_latitudes(latitudes_num)
        bridge = self.bridge
        face_id, point, normal = get_start(bridge.mesh)
        paths = OrderedDict([])
        for i, (latitude, latitude_angle) in enumerate(zip(latitudes, latitude_angles)):
            print(i, latitudes_num)
            path = gather_path(latitude, face_id, point, normal, bridge)
            paths[latitude_angle] = path
        return paths
        
    def __repr__(self):
        return f'Blueprint: {self.path} latitudes_num: {self.latitudes_num}' 

    def get_border_paths(self, angle):        
        assert angle >=0 and angle < 2 * pi
        paths = self.paths
        angle_keys = list(paths.keys())
        for i, angle_key in enumerate(angle_keys):        
            if angle < angle_key:            
                return (paths[angle_keys[i % len(angle_keys)]],
                        paths[angle_keys[(i+1) % len(angle_keys)]])
        return (paths[angle_keys[0]], paths[angle_keys[-1]])

    def grid_sample(self, square_no, save_path=None):
        side = (square_no + 1) * 2
        res = self.load_result(save_path) \
            if save_path is not None and os.path.exists(save_path) \
            else self.create_result(side)
        
        face_id, point, normal = get_start(self.bridge.mesh)
        for sq_no in range(square_no+1):
            print(sq_no, res['sq_no'][0])
            if sq_no > res['sq_no'][0]:                                
                side = (sq_no + 1) * 2
                sq_ids = shifted_square_indices(sq_no, square_no)            
                angles_no = len(sq_ids)                          
                for (r, c) in sq_ids:
                    angle = get_angle(r, c, square_no)                    
                    path0, path1 = self.get_border_paths(angle)
                    pnt0, nrm0 = single_path_sample(path0, sq_no, square_no)
                    pnt1, nrm1 = single_path_sample(path1, sq_no, square_no)
                    pnt = (pnt0 + pnt1)/2
                    nrm = F.normalize((nrm0 + nrm1)/2, dim=0)
                    res['points'][0, :, c, r] = pnt
                    res['normals'][0, :, c, r] = nrm                
                    res['grid'][c, r] = float(sq_no)                
                res['sq_no'][0] = sq_no
                self.save_result(res, save_path)
        return res            
        
    def create_result(self, side):
        return {
            'points': torch.zeros(1, 3, side, side),
            'normals': torch.zeros(1, 3, side, side),
            'grid': torch.zeros(side, side) - 9,
            'sq_no': torch.tensor([-1]),
        }
    
    def load_result(self, path):
        loaded = np.load(path)
        
        return {
            'points': torch.tensor(loaded['points']).float(),
            'normals': torch.tensor(loaded['normals']).float(),
            'grid': torch.tensor(loaded['grid']).float(),
            'sq_no': torch.tensor(loaded['sq_no']).long(),
        }
    
    def save_result(self, res, path=None):
        #assert type('s')  == 'str'
        if path is not None:            
            print('path', path, res['sq_no'])
            np.savez_compressed(
                path,
                points=res['points'].numpy(),
                normals=res['normals'].numpy(),
                grid=res['grid'].numpy(),
                sq_no=res['sq_no'].numpy(),
            )
        

#stl_path = './data/vezuvio.stl'
#stl_path = './data/plane.stl'
stl_path = './data/circle.stl'

square_no = 255
blueprint = Blueprint(stl_path, 2048)
print(blueprint)
torch.save(blueprint.paths, f'./data/circle_plane_{len(blueprint.paths)}.pth')
blueprint_path = './data/circle_{}.npz'.format(square_no)
# print(blueprint_path)
res = blueprint.grid_sample(square_no, blueprint_path)
res['points'].shape, res['normals'].shape
# Out:
# 0 2048
# 1 2048
# 2 2048
# 3 2048
# 4 2048
# 5 2048
# 6 2048
# 7 2048
# 8 2048
# 9 2048
# 10 2048
# 11 2048
# 12 2048
# 13 2048
# 14 2048
# 15 2048
# 16 2048
# 17 2048
# 18 2048
# 19 2048
# 20 2048
# 21 2048
# 22 2048
# 23 2048
# 24 2048
# 25 2048
# 26 2048
# 27 2048
# 28 2048
# 29 2048
# 30 2048
# 31 2048
# 32 2048
# 33 2048
# 34 2048
# 35 2048
# 36 2048
# 37 2048
# 38 2048
# 39 2048
# 40 2048
# 41 2048
# 42 2048
# 43 2048
# 44 2048
# 45 2048
# 46 2048
# 47 2048
# 48 2048
# 49 2048
# 50 2048
# 51 2048
# 52 2048
# 53 2048
# 54 2048
# 55 2048
# 56 2048
# 57 2048
# 58 2048
# 59 2048
# 60 2048
# 61 2048
# 62 2048
# 63 2048
# 64 2048
# 65 2048
# 66 2048
# 67 2048
# 68 2048
# 69 2048
# 70 2048
# 71 2048
# 72 2048
# 73 2048
# 74 2048
# 75 2048
# 76 2048
# 77 2048
# 78 2048
# 79 2048
# 80 2048
# 81 2048
# 82 2048
# 83 2048
# 84 2048
# 85 2048
# 86 2048
# 87 2048
# 88 2048
# 89 2048
# 90 2048
# 91 2048
# 92 2048
# 93 2048
# 94 2048
# 95 2048
# 96 2048
# 97 2048
# 98 2048
# 99 2048
# 100 2048
# 101 2048
# 102 2048
# 103 2048
# 104 2048
# 105 2048
# 106 2048
# 107 2048
# 108 2048
# 109 2048
# 110 2048
# 111 2048
# 112 2048
# 113 2048
# 114 2048
# 115 2048
# 116 2048
# 117 2048
# 118 2048
# 119 2048
# 120 2048
# 121 2048
# 122 2048
# 123 2048
# 124 2048
# 125 2048
# 126 2048
# 127 2048
# 128 2048
# 129 2048
# 130 2048
# 131 2048
# 132 2048
# 133 2048
# 134 2048
# 135 2048
# 136 2048
# 137 2048
# 138 2048
# 139 2048
# 140 2048
# 141 2048
# 142 2048
# 143 2048
# 144 2048
# 145 2048
# 146 2048
# 147 2048
# 148 2048
# 149 2048
# 150 2048
# 151 2048
# 152 2048
# 153 2048
# 154 2048
# 155 2048
# 156 2048
# 157 2048
# 158 2048
# 159 2048
# 160 2048
# 161 2048
# 162 2048
# 163 2048
# 164 2048
# 165 2048
# 166 2048
# 167 2048
# 168 2048
# 169 2048
# 170 2048
# 171 2048
# 172 2048
# 173 2048
# 174 2048
# 175 2048
# 176 2048
# 177 2048
# 178 2048
# 179 2048
# 180 2048
# 181 2048
# 182 2048
# 183 2048
# 184 2048
# 185 2048
# 186 2048
# 187 2048
# 188 2048
# 189 2048
# 190 2048
# 191 2048
# 192 2048
# 193 2048
# 194 2048
# 195 2048
# 196 2048
# 197 2048
# 198 2048
# 199 2048
# 200 2048
# 201 2048
# 202 2048
# 203 2048
# 204 2048
# 205 2048
# 206 2048
# 207 2048
# 208 2048
# 209 2048
# 210 2048
# 211 2048
# 212 2048
# 213 2048
# 214 2048
# 215 2048
# 216 2048
# 217 2048
# 218 2048
# 219 2048
# 220 2048
# 221 2048
# 222 2048
# 223 2048
# 224 2048
# 225 2048
# 226 2048
# 227 2048
# 228 2048
# 229 2048
# 230 2048
# 231 2048
# 232 2048
# 233 2048
# 234 2048
# 235 2048
# 236 2048
# 237 2048
# 238 2048
# 239 2048
# 240 2048
# 241 2048
# 242 2048
# 243 2048
# 244 2048
# 245 2048
# 246 2048
# 247 2048
# 248 2048
# 249 2048
# 250 2048
# 251 2048
# 252 2048
# 253 2048
# 254 2048
# 255 2048
# 256 2048
# 257 2048
# 258 2048
# 259 2048
# 260 2048
# 261 2048
# 262 2048
# 263 2048
# 264 2048
# 265 2048
# 266 2048
# 267 2048
# 268 2048
# 269 2048
# 270 2048
# 271 2048
# 272 2048
# 273 2048
# 274 2048
# 275 2048
# 276 2048
# 277 2048
# 278 2048
# 279 2048
# 280 2048
# 281 2048
# 282 2048
# 283 2048
# 284 2048
# 285 2048
# 286 2048
# 287 2048
# 288 2048
# 289 2048
# 290 2048
# 291 2048
# 292 2048
# 293 2048
# 294 2048
# 295 2048
# 296 2048
# 297 2048
# 298 2048
# 299 2048
# 300 2048
# 301 2048
# 302 2048
# 303 2048
# 304 2048
# 305 2048
# 306 2048
# 307 2048
# 308 2048
# 309 2048
# 310 2048
# 311 2048
# 312 2048
# 313 2048
# 314 2048
# 315 2048
# 316 2048
# 317 2048
# 318 2048
# 319 2048
# 320 2048
# 321 2048
# 322 2048
# 323 2048
# 324 2048
# 325 2048
# 326 2048
# 327 2048
# 328 2048
# 329 2048
# 330 2048
# 331 2048
# 332 2048
# 333 2048
# 334 2048
# 335 2048
# 336 2048
# 337 2048
# 338 2048
# 339 2048
# 340 2048
# 341 2048
# 342 2048
# 343 2048
# 344 2048
# 345 2048
# 346 2048
# 347 2048
# 348 2048
# 349 2048
# 350 2048
# 351 2048
# 352 2048
# 353 2048
# 354 2048
# 355 2048
# 356 2048
# 357 2048
# 358 2048
# 359 2048
# 360 2048
# 361 2048
# 362 2048
# 363 2048
# 364 2048
# 365 2048
# 366 2048
# 367 2048
# 368 2048
# 369 2048
# 370 2048
# 371 2048
# 372 2048
# 373 2048
# 374 2048
# 375 2048
# 376 2048
# 377 2048
# 378 2048
# 379 2048
# 380 2048
# 381 2048
# 382 2048
# 383 2048
# 384 2048
# 385 2048
# 386 2048
# 387 2048
# 388 2048
# 389 2048
# 390 2048
# 391 2048
# 392 2048
# 393 2048
# 394 2048
# 395 2048
# 396 2048
# 397 2048
# 398 2048
# 399 2048
# 400 2048
# 401 2048
# 402 2048
# 403 2048
# 404 2048
# 405 2048
# 406 2048
# 407 2048
# 408 2048
# 409 2048
# 410 2048
# 411 2048
# 412 2048
# 413 2048
# 414 2048
# 415 2048
# 416 2048
# 417 2048
# 418 2048
# 419 2048
# 420 2048
# 421 2048
# 422 2048
# 423 2048
# 424 2048
# 425 2048
# 426 2048
# 427 2048
# 428 2048
# 429 2048
# 430 2048
# 431 2048
# 432 2048
# 433 2048
# 434 2048
# 435 2048
# 436 2048
# 437 2048
# 438 2048
# 439 2048
# 440 2048
# 441 2048
# 442 2048
# 443 2048
# 444 2048
# 445 2048
# 446 2048
# 447 2048
# 448 2048
# 449 2048
# 450 2048
# 451 2048
# 452 2048
# 453 2048
# 454 2048
# 455 2048
# 456 2048
# 457 2048
# 458 2048
# 459 2048
# 460 2048
# 461 2048
# 462 2048
# 463 2048
# 464 2048
# 465 2048
# 466 2048
# 467 2048
# 468 2048
# 469 2048
# 470 2048
# 471 2048
# 472 2048
# 473 2048
# 474 2048
# 475 2048
# 476 2048
# 477 2048
# 478 2048
# 479 2048
# 480 2048
# 481 2048
# 482 2048
# 483 2048
# 484 2048
# 485 2048
# 486 2048
# 487 2048
# 488 2048
# 489 2048
# 490 2048
# 491 2048
# 492 2048
# 493 2048
# 494 2048
# 495 2048
# 496 2048
# 497 2048
# 498 2048
# 499 2048
# 500 2048
# 501 2048
# 502 2048
# 503 2048
# 504 2048
# 505 2048
# 506 2048
# 507 2048
# 508 2048
# 509 2048
# 510 2048
# 511 2048
# 512 2048
# 513 2048
# 514 2048
# 515 2048
# 516 2048
# 517 2048
# 518 2048
# 519 2048
# 520 2048
# 521 2048
# 522 2048
# 523 2048
# 524 2048
# 525 2048
# 526 2048
# 527 2048
# 528 2048
# 529 2048
# 530 2048
# 531 2048
# 532 2048
# 533 2048
# 534 2048
# 535 2048
# 536 2048
# 537 2048
# 538 2048
# 539 2048
# 540 2048
# 541 2048
# 542 2048
# 543 2048
# 544 2048
# 545 2048
# 546 2048
# 547 2048
# 548 2048
# 549 2048
# 550 2048
# 551 2048
# 552 2048
# 553 2048
# 554 2048
# 555 2048
# 556 2048
# 557 2048
# 558 2048
# 559 2048
# 560 2048
# 561 2048
# 562 2048
# 563 2048
# 564 2048
# 565 2048
# 566 2048
# 567 2048
# 568 2048
# 569 2048
# 570 2048
# 571 2048
# 572 2048
# 573 2048
# 574 2048
# 575 2048
# 576 2048
# 577 2048
# 578 2048
# 579 2048
# 580 2048
# 581 2048
# 582 2048
# 583 2048
# 584 2048
# 585 2048
# 586 2048
# 587 2048
# 588 2048
# 589 2048
# 590 2048
# 591 2048
# 592 2048
# 593 2048
# 594 2048
# 595 2048
# 596 2048
# 597 2048
# 598 2048
# 599 2048
# 600 2048
# 601 2048
# 602 2048
# 603 2048
# 604 2048
# 605 2048
# 606 2048
# 607 2048
# 608 2048
# 609 2048
# 610 2048
# 611 2048
# 612 2048
# 613 2048
# 614 2048
# 615 2048
# 616 2048
# 617 2048
# 618 2048
# 619 2048
# 620 2048
# 621 2048
# 622 2048
# 623 2048
# 624 2048
# 625 2048
# 626 2048
# 627 2048
# 628 2048
# 629 2048
# 630 2048
# 631 2048
# 632 2048
# 633 2048
# 634 2048
# 635 2048
# 636 2048
# 637 2048
# 638 2048
# 639 2048
# 640 2048
# 641 2048
# 642 2048
# 643 2048
# 644 2048
# 645 2048
# 646 2048
# 647 2048
# 648 2048
# 649 2048
# 650 2048
# 651 2048
# 652 2048
# 653 2048
# 654 2048
# 655 2048
# 656 2048
# 657 2048
# 658 2048
# 659 2048
# 660 2048
# 661 2048
# 662 2048
# 663 2048
# 664 2048
# 665 2048
# 666 2048
# 667 2048
# 668 2048
# 669 2048
# 670 2048
# 671 2048
# 672 2048
# 673 2048
# 674 2048
# 675 2048
# 676 2048
# 677 2048
# 678 2048
# 679 2048
# 680 2048
# 681 2048
# 682 2048
# 683 2048
# 684 2048
# 685 2048
# 686 2048
# 687 2048
# 688 2048
# 689 2048
# 690 2048
# 691 2048
# 692 2048
# 693 2048
# 694 2048
# 695 2048
# 696 2048
# 697 2048
# 698 2048
# 699 2048
# 700 2048
# 701 2048
# 702 2048
# 703 2048
# 704 2048
# 705 2048
# 706 2048
# 707 2048
# 708 2048
# 709 2048
# 710 2048
# 711 2048
# 712 2048
# 713 2048
# 714 2048
# 715 2048
# 716 2048
# 717 2048
# 718 2048
# 719 2048
# 720 2048
# 721 2048
# 722 2048
# 723 2048
# 724 2048
# 725 2048
# 726 2048
# 727 2048
# 728 2048
# 729 2048
# 730 2048
# 731 2048
# 732 2048
# 733 2048
# 734 2048
# 735 2048
# 736 2048
# 737 2048
# 738 2048
# 739 2048
# 740 2048
# 741 2048
# 742 2048
# 743 2048
# 744 2048
# 745 2048
# 746 2048
# 747 2048
# 748 2048
# 749 2048
# 750 2048
# 751 2048
# 752 2048
# 753 2048
# 754 2048
# 755 2048
# 756 2048
# 757 2048
# 758 2048
# 759 2048
# 760 2048
# 761 2048
# 762 2048
# 763 2048
# 764 2048
# 765 2048
# 766 2048
# 767 2048
# 768 2048
# 769 2048
# 770 2048
# 771 2048
# 772 2048
# 773 2048
# 774 2048
# 775 2048
# 776 2048
# 777 2048
# 778 2048
# 779 2048
# 780 2048
# 781 2048
# 782 2048
# 783 2048
# 784 2048
# 785 2048
# 786 2048
# 787 2048
# 788 2048
# 789 2048
# 790 2048
# 791 2048
# 792 2048
# 793 2048
# 794 2048
# 795 2048
# 796 2048
# 797 2048
# 798 2048
# 799 2048
# 800 2048
# 801 2048
# 802 2048
# 803 2048
# 804 2048
# 805 2048
# 806 2048
# 807 2048
# 808 2048
# 809 2048
# 810 2048
# 811 2048
# 812 2048
# 813 2048
# 814 2048
# 815 2048
# 816 2048
# 817 2048
# 818 2048
# 819 2048
# 820 2048
# 821 2048
# 822 2048
# 823 2048
# 824 2048
# 825 2048
# 826 2048
# 827 2048
# 828 2048
# 829 2048
# 830 2048
# 831 2048
# 832 2048
# 833 2048
# 834 2048
# 835 2048
# 836 2048
# 837 2048
# 838 2048
# 839 2048
# 840 2048
# 841 2048
# 842 2048
# 843 2048
# 844 2048
# 845 2048
# 846 2048
# 847 2048
# 848 2048
# 849 2048
# 850 2048
# 851 2048
# 852 2048
# 853 2048
# 854 2048
# 855 2048
# 856 2048
# 857 2048
# 858 2048
# 859 2048
# 860 2048
# 861 2048
# 862 2048
# 863 2048
# 864 2048
# 865 2048
# 866 2048
# 867 2048
# 868 2048
# 869 2048
# 870 2048
# 871 2048
# 872 2048
# 873 2048
# 874 2048
# 875 2048
# 876 2048
# 877 2048
# 878 2048
# 879 2048
# 880 2048
# 881 2048
# 882 2048
# 883 2048
# 884 2048
# 885 2048
# 886 2048
# 887 2048
# 888 2048
# 889 2048
# 890 2048
# 891 2048
# 892 2048
# 893 2048
# 894 2048
# 895 2048
# 896 2048
# 897 2048
# 898 2048
# 899 2048
# 900 2048
# 901 2048
# 902 2048
# 903 2048
# 904 2048
# 905 2048
# 906 2048
# 907 2048
# 908 2048
# 909 2048
# 910 2048
# 911 2048
# 912 2048
# 913 2048
# 914 2048
# 915 2048
# 916 2048
# 917 2048
# 918 2048
# 919 2048
# 920 2048
# 921 2048
# 922 2048
# 923 2048
# 924 2048
# 925 2048
# 926 2048
# 927 2048
# 928 2048
# 929 2048
# 930 2048
# 931 2048
# 932 2048
# 933 2048
# 934 2048
# 935 2048
# 936 2048
# 937 2048
# 938 2048
# 939 2048
# 940 2048
# 941 2048
# 942 2048
# 943 2048
# 944 2048
# 945 2048
# 946 2048
# 947 2048
# 948 2048
# 949 2048
# 950 2048
# 951 2048
# 952 2048
# 953 2048
# 954 2048
# 955 2048
# 956 2048
# 957 2048
# 958 2048
# 959 2048
# 960 2048
# 961 2048
# 962 2048
# 963 2048
# 964 2048
# 965 2048
# 966 2048
# 967 2048
# 968 2048
# 969 2048
# 970 2048
# 971 2048
# 972 2048
# 973 2048
# 974 2048
# 975 2048
# 976 2048
# 977 2048
# 978 2048
# 979 2048
# 980 2048
# 981 2048
# 982 2048
# 983 2048
# 984 2048
# 985 2048
# 986 2048
# 987 2048
# 988 2048
# 989 2048
# 990 2048
# 991 2048
# 992 2048
# 993 2048
# 994 2048
# 995 2048
# 996 2048
# 997 2048
# 998 2048
# 999 2048
# 1000 2048
# 1001 2048
# 1002 2048
# 1003 2048
# 1004 2048
# 1005 2048
# 1006 2048
# 1007 2048
# 1008 2048
# 1009 2048
# 1010 2048
# 1011 2048
# 1012 2048
# 1013 2048
# 1014 2048
# 1015 2048
# 1016 2048
# 1017 2048
# 1018 2048
# 1019 2048
# 1020 2048
# 1021 2048
# 1022 2048
# 1023 2048
# 1024 2048
# 1025 2048
# 1026 2048
# 1027 2048
# 1028 2048
# 1029 2048
# 1030 2048
# 1031 2048
# 1032 2048
# 1033 2048
# 1034 2048
# 1035 2048
# 1036 2048
# 1037 2048
# 1038 2048
# 1039 2048
# 1040 2048
# 1041 2048
# 1042 2048
# 1043 2048
# 1044 2048
# 1045 2048
# 1046 2048
# 1047 2048
# 1048 2048
# 1049 2048
# 1050 2048
# 1051 2048
# 1052 2048
# 1053 2048
# 1054 2048
# 1055 2048
# 1056 2048
# 1057 2048
# 1058 2048
# 1059 2048
# 1060 2048
# 1061 2048
# 1062 2048
# 1063 2048
# 1064 2048
# 1065 2048
# 1066 2048
# 1067 2048
# 1068 2048
# 1069 2048
# 1070 2048
# 1071 2048
# 1072 2048
# 1073 2048
# 1074 2048
# 1075 2048
# 1076 2048
# 1077 2048
# 1078 2048
# 1079 2048
# 1080 2048
# 1081 2048
# 1082 2048
# 1083 2048
# 1084 2048
# 1085 2048
# 1086 2048
# 1087 2048
# 1088 2048
# 1089 2048
# 1090 2048
# 1091 2048
# 1092 2048
# 1093 2048
# 1094 2048
# 1095 2048
# 1096 2048
# 1097 2048
# 1098 2048
# 1099 2048
# 1100 2048
# 1101 2048
# 1102 2048
# 1103 2048
# 1104 2048
# 1105 2048
# 1106 2048
# 1107 2048
# 1108 2048
# 1109 2048
# 1110 2048
# 1111 2048
# 1112 2048
# 1113 2048
# 1114 2048
# 1115 2048
# 1116 2048
# 1117 2048
# 1118 2048
# 1119 2048
# 1120 2048
# 1121 2048
# 1122 2048
# 1123 2048
# 1124 2048
# 1125 2048
# 1126 2048
# 1127 2048
# 1128 2048
# 1129 2048
# 1130 2048
# 1131 2048
# 1132 2048
# 1133 2048
# 1134 2048
# 1135 2048
# 1136 2048
# 1137 2048
# 1138 2048
# 1139 2048
# 1140 2048
# 1141 2048
# 1142 2048
# 1143 2048
# 1144 2048
# 1145 2048
# 1146 2048
# 1147 2048
# 1148 2048
# 1149 2048
# 1150 2048
# 1151 2048
# 1152 2048
# 1153 2048
# 1154 2048
# 1155 2048
# 1156 2048
# 1157 2048
# 1158 2048
# 1159 2048
# 1160 2048
# 1161 2048
# 1162 2048
# 1163 2048
# 1164 2048
# 1165 2048
# 1166 2048
# 1167 2048
# 1168 2048
# 1169 2048
# 1170 2048
# 1171 2048
# 1172 2048
# 1173 2048
# 1174 2048
# 1175 2048
# 1176 2048
# 1177 2048
# 1178 2048
# 1179 2048
# 1180 2048
# 1181 2048
# 1182 2048
# 1183 2048
# 1184 2048
# 1185 2048
# 1186 2048
# 1187 2048
# 1188 2048
# 1189 2048
# 1190 2048
# 1191 2048
# 1192 2048
# 1193 2048
# 1194 2048
# 1195 2048
# 1196 2048
# 1197 2048
# 1198 2048
# 1199 2048
# 1200 2048
# 1201 2048
# 1202 2048
# 1203 2048
# 1204 2048
# 1205 2048
# 1206 2048
# 1207 2048
# 1208 2048
# 1209 2048
# 1210 2048
# 1211 2048
# 1212 2048
# 1213 2048
# 1214 2048
# 1215 2048
# 1216 2048
# 1217 2048
# 1218 2048
# 1219 2048
# 1220 2048
# 1221 2048
# 1222 2048
# 1223 2048
# 1224 2048
# 1225 2048
# 1226 2048
# 1227 2048
# 1228 2048
# 1229 2048
# 1230 2048
# 1231 2048
# 1232 2048
# 1233 2048
# 1234 2048
# 1235 2048
# 1236 2048
# 1237 2048
# 1238 2048
# 1239 2048
# 1240 2048
# 1241 2048
# 1242 2048
# 1243 2048
# 1244 2048
# 1245 2048
# 1246 2048
# 1247 2048
# 1248 2048
# 1249 2048
# 1250 2048
# 1251 2048
# 1252 2048
# 1253 2048
# 1254 2048
# 1255 2048
# 1256 2048
# 1257 2048
# 1258 2048
# 1259 2048
# 1260 2048
# 1261 2048
# 1262 2048
# 1263 2048
# 1264 2048
# 1265 2048
# 1266 2048
# 1267 2048
# 1268 2048
# 1269 2048
# 1270 2048
# 1271 2048
# 1272 2048
# 1273 2048
# 1274 2048
# 1275 2048
# 1276 2048
# 1277 2048
# 1278 2048
# 1279 2048
# 1280 2048
# 1281 2048
# 1282 2048
# 1283 2048
# 1284 2048
# 1285 2048
# 1286 2048
# 1287 2048
# 1288 2048
# 1289 2048
# 1290 2048
# 1291 2048
# 1292 2048
# 1293 2048
# 1294 2048
# 1295 2048
# 1296 2048
# 1297 2048
# 1298 2048
# 1299 2048
# 1300 2048
# 1301 2048
# 1302 2048
# 1303 2048
# 1304 2048
# 1305 2048
# 1306 2048
# 1307 2048
# 1308 2048
# 1309 2048
# 1310 2048
# 1311 2048
# 1312 2048
# 1313 2048
# 1314 2048
# 1315 2048
# 1316 2048
# 1317 2048
# 1318 2048
# 1319 2048
# 1320 2048
# 1321 2048
# 1322 2048
# 1323 2048
# 1324 2048
# 1325 2048
# 1326 2048
# 1327 2048
# 1328 2048
# 1329 2048
# 1330 2048
# 1331 2048
# 1332 2048
# 1333 2048
# 1334 2048
# 1335 2048
# 1336 2048
# 1337 2048
# 1338 2048
# 1339 2048
# 1340 2048
# 1341 2048
# 1342 2048
# 1343 2048
# 1344 2048
# 1345 2048
# 1346 2048
# 1347 2048
# 1348 2048
# 1349 2048
# 1350 2048
# 1351 2048
# 1352 2048
# 1353 2048
# 1354 2048
# 1355 2048
# 1356 2048
# 1357 2048
# 1358 2048
# 1359 2048
# 1360 2048
# 1361 2048
# 1362 2048
# 1363 2048
# 1364 2048
# 1365 2048
# 1366 2048
# 1367 2048
# 1368 2048
# 1369 2048
# 1370 2048
# 1371 2048
# 1372 2048
# 1373 2048
# 1374 2048
# 1375 2048
# 1376 2048
# 1377 2048
# 1378 2048
# 1379 2048
# 1380 2048
# 1381 2048
# 1382 2048
# 1383 2048
# 1384 2048
# 1385 2048
# 1386 2048
# 1387 2048
# 1388 2048
# 1389 2048
# 1390 2048
# 1391 2048
# 1392 2048
# 1393 2048
# 1394 2048
# 1395 2048
# 1396 2048
# 1397 2048
# 1398 2048
# 1399 2048
# 1400 2048
# 1401 2048
# 1402 2048
# 1403 2048
# 1404 2048
# 1405 2048
# 1406 2048
# 1407 2048
# 1408 2048
# 1409 2048
# 1410 2048
# 1411 2048
# 1412 2048
# 1413 2048
# 1414 2048
# 1415 2048
# 1416 2048
# 1417 2048
# 1418 2048
# 1419 2048
# 1420 2048
# 1421 2048
# 1422 2048
# 1423 2048
# 1424 2048
# 1425 2048
# 1426 2048
# 1427 2048
# 1428 2048
# 1429 2048
# 1430 2048
# 1431 2048
# 1432 2048
# 1433 2048
# 1434 2048
# 1435 2048
# 1436 2048
# 1437 2048
# 1438 2048
# 1439 2048
# 1440 2048
# 1441 2048
# 1442 2048
# 1443 2048
# 1444 2048
# 1445 2048
# 1446 2048
# 1447 2048
# 1448 2048
# 1449 2048
# 1450 2048
# 1451 2048
# 1452 2048
# 1453 2048
# 1454 2048
# 1455 2048
# 1456 2048
# 1457 2048
# 1458 2048
# 1459 2048
# 1460 2048
# 1461 2048
# 1462 2048
# 1463 2048
# 1464 2048
# 1465 2048
# 1466 2048
# 1467 2048
# 1468 2048
# 1469 2048
# 1470 2048
# 1471 2048
# 1472 2048
# 1473 2048
# 1474 2048
# 1475 2048
# 1476 2048
# 1477 2048
# 1478 2048
# 1479 2048
# 1480 2048
# 1481 2048
# 1482 2048
# 1483 2048
# 1484 2048
# 1485 2048
# 1486 2048
# 1487 2048
# 1488 2048
# 1489 2048
# 1490 2048
# 1491 2048
# 1492 2048
# 1493 2048
# 1494 2048
# 1495 2048
# 1496 2048
# 1497 2048
# 1498 2048
# 1499 2048
# 1500 2048
# 1501 2048
# 1502 2048
# 1503 2048
# 1504 2048
# 1505 2048
# 1506 2048
# 1507 2048
# 1508 2048
# 1509 2048
# 1510 2048
# 1511 2048
# 1512 2048
# 1513 2048
# 1514 2048
# 1515 2048
# 1516 2048
# 1517 2048
# 1518 2048
# 1519 2048
# 1520 2048
# 1521 2048
# 1522 2048
# 1523 2048
# 1524 2048
# 1525 2048
# 1526 2048
# 1527 2048
# 1528 2048
# 1529 2048
# 1530 2048
# 1531 2048
# 1532 2048
# 1533 2048
# 1534 2048
# 1535 2048
# 1536 2048
# 1537 2048
# 1538 2048
# 1539 2048
# 1540 2048
# 1541 2048
# 1542 2048
# 1543 2048
# 1544 2048
# 1545 2048
# 1546 2048
# 1547 2048
# 1548 2048
# 1549 2048
# 1550 2048
# 1551 2048
# 1552 2048
# 1553 2048
# 1554 2048
# 1555 2048
# 1556 2048
# 1557 2048
# 1558 2048
# 1559 2048
# 1560 2048
# 1561 2048
# 1562 2048
# 1563 2048
# 1564 2048
# 1565 2048
# 1566 2048
# 1567 2048
# 1568 2048
# 1569 2048
# 1570 2048
# 1571 2048
# 1572 2048
# 1573 2048
# 1574 2048
# 1575 2048
# 1576 2048
# 1577 2048
# 1578 2048
# 1579 2048
# 1580 2048
# 1581 2048
# 1582 2048
# 1583 2048
# 1584 2048
# 1585 2048
# 1586 2048
# 1587 2048
# 1588 2048
# 1589 2048
# 1590 2048
# 1591 2048
# 1592 2048
# 1593 2048
# 1594 2048
# 1595 2048
# 1596 2048
# 1597 2048
# 1598 2048
# 1599 2048
# 1600 2048
# 1601 2048
# 1602 2048
# 1603 2048
# 1604 2048
# 1605 2048
# 1606 2048
# 1607 2048
# 1608 2048
# 1609 2048
# 1610 2048
# 1611 2048
# 1612 2048
# 1613 2048
# 1614 2048
# 1615 2048
# 1616 2048
# 1617 2048
# 1618 2048
# 1619 2048
# 1620 2048
# 1621 2048
# 1622 2048
# 1623 2048
# 1624 2048
# 1625 2048
# 1626 2048
# 1627 2048
# 1628 2048
# 1629 2048
# 1630 2048
# 1631 2048
# 1632 2048
# 1633 2048
# 1634 2048
# 1635 2048
# 1636 2048
# 1637 2048
# 1638 2048
# 1639 2048
# 1640 2048
# 1641 2048
# 1642 2048
# 1643 2048
# 1644 2048
# 1645 2048
# 1646 2048
# 1647 2048
# 1648 2048
# 1649 2048
# 1650 2048
# 1651 2048
# 1652 2048
# 1653 2048
# 1654 2048
# 1655 2048
# 1656 2048
# 1657 2048
# 1658 2048
# 1659 2048
# 1660 2048
# 1661 2048
# 1662 2048
# 1663 2048
# 1664 2048
# 1665 2048
# 1666 2048
# 1667 2048
# 1668 2048
# 1669 2048
# 1670 2048
# 1671 2048
# 1672 2048
# 1673 2048
# 1674 2048
# 1675 2048
# 1676 2048
# 1677 2048
# 1678 2048
# 1679 2048
# 1680 2048
# 1681 2048
# 1682 2048
# 1683 2048
# 1684 2048
# 1685 2048
# 1686 2048
# 1687 2048
# 1688 2048
# 1689 2048
# 1690 2048
# 1691 2048
# 1692 2048
# 1693 2048
# 1694 2048
# 1695 2048
# 1696 2048
# 1697 2048
# 1698 2048
# 1699 2048
# 1700 2048
# 1701 2048
# 1702 2048
# 1703 2048
# 1704 2048
# 1705 2048
# 1706 2048
# 1707 2048
# 1708 2048
# 1709 2048
# 1710 2048
# 1711 2048
# 1712 2048
# 1713 2048
# 1714 2048
# 1715 2048
# 1716 2048
# 1717 2048
# 1718 2048
# 1719 2048
# 1720 2048
# 1721 2048
# 1722 2048
# 1723 2048
# 1724 2048
# 1725 2048
# 1726 2048
# 1727 2048
# 1728 2048
# 1729 2048
# 1730 2048
# 1731 2048
# 1732 2048
# 1733 2048
# 1734 2048
# 1735 2048
# 1736 2048
# 1737 2048
# 1738 2048
# 1739 2048
# 1740 2048
# 1741 2048
# 1742 2048
# 1743 2048
# 1744 2048
# 1745 2048
# 1746 2048
# 1747 2048
# 1748 2048
# 1749 2048
# 1750 2048
# 1751 2048
# 1752 2048
# 1753 2048
# 1754 2048
# 1755 2048
# 1756 2048
# 1757 2048
# 1758 2048
# 1759 2048
# 1760 2048
# 1761 2048
# 1762 2048
# 1763 2048
# 1764 2048
# 1765 2048
# 1766 2048
# 1767 2048
# 1768 2048
# 1769 2048
# 1770 2048
# 1771 2048
# 1772 2048
# 1773 2048
# 1774 2048
# 1775 2048
# 1776 2048
# 1777 2048
# 1778 2048
# 1779 2048
# 1780 2048
# 1781 2048
# 1782 2048
# 1783 2048
# 1784 2048
# 1785 2048
# 1786 2048
# 1787 2048
# 1788 2048
# 1789 2048
# 1790 2048
# 1791 2048
# 1792 2048
# 1793 2048
# 1794 2048
# 1795 2048
# 1796 2048
# 1797 2048
# 1798 2048
# 1799 2048
# 1800 2048
# 1801 2048
# 1802 2048
# 1803 2048
# 1804 2048
# 1805 2048
# 1806 2048
# 1807 2048
# 1808 2048
# 1809 2048
# 1810 2048
# 1811 2048
# 1812 2048
# 1813 2048
# 1814 2048
# 1815 2048
# 1816 2048
# 1817 2048
# 1818 2048
# 1819 2048
# 1820 2048
# 1821 2048
# 1822 2048
# 1823 2048
# 1824 2048
# 1825 2048
# 1826 2048
# 1827 2048
# 1828 2048
# 1829 2048
# 1830 2048
# 1831 2048
# 1832 2048
# 1833 2048
# 1834 2048
# 1835 2048
# 1836 2048
# 1837 2048
# 1838 2048
# 1839 2048
# 1840 2048
# 1841 2048
# 1842 2048
# 1843 2048
# 1844 2048
# 1845 2048
# 1846 2048
# 1847 2048
# 1848 2048
# 1849 2048
# 1850 2048
# 1851 2048
# 1852 2048
# 1853 2048
# 1854 2048
# 1855 2048
# 1856 2048
# 1857 2048
# 1858 2048
# 1859 2048
# 1860 2048
# 1861 2048
# 1862 2048
# 1863 2048
# 1864 2048
# 1865 2048
# 1866 2048
# 1867 2048
# 1868 2048
# 1869 2048
# 1870 2048
# 1871 2048
# 1872 2048
# 1873 2048
# 1874 2048
# 1875 2048
# 1876 2048
# 1877 2048
# 1878 2048
# 1879 2048
# 1880 2048
# 1881 2048
# 1882 2048
# 1883 2048
# 1884 2048
# 1885 2048
# 1886 2048
# 1887 2048
# 1888 2048
# 1889 2048
# 1890 2048
# 1891 2048
# 1892 2048
# 1893 2048
# 1894 2048
# 1895 2048
# 1896 2048
# 1897 2048
# 1898 2048
# 1899 2048
# 1900 2048
# 1901 2048
# 1902 2048
# 1903 2048
# 1904 2048
# 1905 2048
# 1906 2048
# 1907 2048
# 1908 2048
# 1909 2048
# 1910 2048
# 1911 2048
# 1912 2048
# 1913 2048
# 1914 2048
# 1915 2048
# 1916 2048
# 1917 2048
# 1918 2048
# 1919 2048
# 1920 2048
# 1921 2048
# 1922 2048
# 1923 2048
# 1924 2048
# 1925 2048
# 1926 2048
# 1927 2048
# 1928 2048
# 1929 2048
# 1930 2048
# 1931 2048
# 1932 2048
# 1933 2048
# 1934 2048
# 1935 2048
# 1936 2048
# 1937 2048
# 1938 2048
# 1939 2048
# 1940 2048
# 1941 2048
# 1942 2048
# 1943 2048
# 1944 2048
# 1945 2048
# 1946 2048
# 1947 2048
# 1948 2048
# 1949 2048
# 1950 2048
# 1951 2048
# 1952 2048
# 1953 2048
# 1954 2048
# 1955 2048
# 1956 2048
# 1957 2048
# 1958 2048
# 1959 2048
# 1960 2048
# 1961 2048
# 1962 2048
# 1963 2048
# 1964 2048
# 1965 2048
# 1966 2048
# 1967 2048
# 1968 2048
# 1969 2048
# 1970 2048
# 1971 2048
# 1972 2048
# 1973 2048
# 1974 2048
# 1975 2048
# 1976 2048
# 1977 2048
# 1978 2048
# 1979 2048
# 1980 2048
# 1981 2048
# 1982 2048
# 1983 2048
# 1984 2048
# 1985 2048
# 1986 2048
# 1987 2048
# 1988 2048
# 1989 2048
# 1990 2048
# 1991 2048
# 1992 2048
# 1993 2048
# 1994 2048
# 1995 2048
# 1996 2048
# 1997 2048
# 1998 2048
# 1999 2048
# 2000 2048
# 2001 2048
# 2002 2048
# 2003 2048
# 2004 2048
# 2005 2048
# 2006 2048
# 2007 2048
# 2008 2048
# 2009 2048
# 2010 2048
# 2011 2048
# 2012 2048
# 2013 2048
# 2014 2048
# 2015 2048
# 2016 2048
# 2017 2048
# 2018 2048
# 2019 2048
# 2020 2048
# 2021 2048
# 2022 2048
# 2023 2048
# 2024 2048
# 2025 2048
# 2026 2048
# 2027 2048
# 2028 2048
# 2029 2048
# 2030 2048
# 2031 2048
# 2032 2048
# 2033 2048
# 2034 2048
# 2035 2048
# 2036 2048
# 2037 2048
# 2038 2048
# 2039 2048
# 2040 2048
# 2041 2048
# 2042 2048
# 2043 2048
# 2044 2048
# 2045 2048
# 2046 2048
# 2047 2048
# Blueprint: ./data/circle.stl latitudes_num: 2048
# 0 tensor(-1)
# path ./data/circle_255.npz tensor([0])
# 1 tensor(0)
# path ./data/circle_255.npz tensor([1])
# 2 tensor(1)
# path ./data/circle_255.npz tensor([2])
# 3 tensor(2)
# path ./data/circle_255.npz tensor([3])
# 4 tensor(3)
# path ./data/circle_255.npz tensor([4])
# 5 tensor(4)
# path ./data/circle_255.npz tensor([5])
# 6 tensor(5)
# path ./data/circle_255.npz tensor([6])
# 7 tensor(6)
# path ./data/circle_255.npz tensor([7])
# 8 tensor(7)
# path ./data/circle_255.npz tensor([8])
# 9 tensor(8)
# path ./data/circle_255.npz tensor([9])
# 10 tensor(9)
# path ./data/circle_255.npz tensor([10])
# 11 tensor(10)
# path ./data/circle_255.npz tensor([11])
# 12 tensor(11)
# path ./data/circle_255.npz tensor([12])
# 13 tensor(12)
# path ./data/circle_255.npz tensor([13])
# 14 tensor(13)
# path ./data/circle_255.npz tensor([14])
# 15 tensor(14)
# path ./data/circle_255.npz tensor([15])
# 16 tensor(15)
# path ./data/circle_255.npz tensor([16])
# 17 tensor(16)
# path ./data/circle_255.npz tensor([17])
# 18 tensor(17)
# path ./data/circle_255.npz tensor([18])
# 19 tensor(18)
# path ./data/circle_255.npz tensor([19])
# 20 tensor(19)
# path ./data/circle_255.npz tensor([20])
# 21 tensor(20)
# path ./data/circle_255.npz tensor([21])
# 22 tensor(21)
# path ./data/circle_255.npz tensor([22])
# 23 tensor(22)
# path ./data/circle_255.npz tensor([23])
# 24 tensor(23)
# path ./data/circle_255.npz tensor([24])
# 25 tensor(24)
# path ./data/circle_255.npz tensor([25])
# 26 tensor(25)
# path ./data/circle_255.npz tensor([26])
# 27 tensor(26)
# path ./data/circle_255.npz tensor([27])
# 28 tensor(27)
# path ./data/circle_255.npz tensor([28])
# 29 tensor(28)
# path ./data/circle_255.npz tensor([29])
# 30 tensor(29)
# path ./data/circle_255.npz tensor([30])
# 31 tensor(30)
# path ./data/circle_255.npz tensor([31])
# 32 tensor(31)
# path ./data/circle_255.npz tensor([32])
# 33 tensor(32)
# path ./data/circle_255.npz tensor([33])
# 34 tensor(33)
# path ./data/circle_255.npz tensor([34])
# 35 tensor(34)
# path ./data/circle_255.npz tensor([35])
# 36 tensor(35)
# path ./data/circle_255.npz tensor([36])
# 37 tensor(36)
# path ./data/circle_255.npz tensor([37])
# 38 tensor(37)
# path ./data/circle_255.npz tensor([38])
# 39 tensor(38)
# path ./data/circle_255.npz tensor([39])
# 40 tensor(39)
# path ./data/circle_255.npz tensor([40])
# 41 tensor(40)
# path ./data/circle_255.npz tensor([41])
# 42 tensor(41)
# path ./data/circle_255.npz tensor([42])
# 43 tensor(42)
# path ./data/circle_255.npz tensor([43])
# 44 tensor(43)
# path ./data/circle_255.npz tensor([44])
# 45 tensor(44)
# path ./data/circle_255.npz tensor([45])
# 46 tensor(45)
# path ./data/circle_255.npz tensor([46])
# 47 tensor(46)
# path ./data/circle_255.npz tensor([47])
# 48 tensor(47)
# path ./data/circle_255.npz tensor([48])
# 49 tensor(48)
# path ./data/circle_255.npz tensor([49])
# 50 tensor(49)
# path ./data/circle_255.npz tensor([50])
# 51 tensor(50)
# path ./data/circle_255.npz tensor([51])
# 52 tensor(51)
# path ./data/circle_255.npz tensor([52])
# 53 tensor(52)
# path ./data/circle_255.npz tensor([53])
# 54 tensor(53)
# path ./data/circle_255.npz tensor([54])
# 55 tensor(54)
# path ./data/circle_255.npz tensor([55])
# 56 tensor(55)
# path ./data/circle_255.npz tensor([56])
# 57 tensor(56)
# path ./data/circle_255.npz tensor([57])
# 58 tensor(57)
# path ./data/circle_255.npz tensor([58])
# 59 tensor(58)
# path ./data/circle_255.npz tensor([59])
# 60 tensor(59)
# path ./data/circle_255.npz tensor([60])
# 61 tensor(60)
# path ./data/circle_255.npz tensor([61])
# 62 tensor(61)
# path ./data/circle_255.npz tensor([62])
# 63 tensor(62)
# path ./data/circle_255.npz tensor([63])
# 64 tensor(63)
# path ./data/circle_255.npz tensor([64])
# 65 tensor(64)
# path ./data/circle_255.npz tensor([65])
# 66 tensor(65)
# path ./data/circle_255.npz tensor([66])
# 67 tensor(66)
# path ./data/circle_255.npz tensor([67])
# 68 tensor(67)
# path ./data/circle_255.npz tensor([68])
# 69 tensor(68)
# path ./data/circle_255.npz tensor([69])
# 70 tensor(69)
# path ./data/circle_255.npz tensor([70])
# 71 tensor(70)
# path ./data/circle_255.npz tensor([71])
# 72 tensor(71)
# path ./data/circle_255.npz tensor([72])
# 73 tensor(72)
# path ./data/circle_255.npz tensor([73])
# 74 tensor(73)
# path ./data/circle_255.npz tensor([74])
# 75 tensor(74)
# path ./data/circle_255.npz tensor([75])
# 76 tensor(75)
# path ./data/circle_255.npz tensor([76])
# 77 tensor(76)
# path ./data/circle_255.npz tensor([77])
# 78 tensor(77)
# path ./data/circle_255.npz tensor([78])
# 79 tensor(78)
# path ./data/circle_255.npz tensor([79])
# 80 tensor(79)
# path ./data/circle_255.npz tensor([80])
# 81 tensor(80)
# path ./data/circle_255.npz tensor([81])
# 82 tensor(81)
# path ./data/circle_255.npz tensor([82])
# 83 tensor(82)
# path ./data/circle_255.npz tensor([83])
# 84 tensor(83)
# path ./data/circle_255.npz tensor([84])
# 85 tensor(84)
# path ./data/circle_255.npz tensor([85])
# 86 tensor(85)
# path ./data/circle_255.npz tensor([86])
# 87 tensor(86)
# path ./data/circle_255.npz tensor([87])
# 88 tensor(87)
# path ./data/circle_255.npz tensor([88])
# 89 tensor(88)
# path ./data/circle_255.npz tensor([89])
# 90 tensor(89)
# path ./data/circle_255.npz tensor([90])
# 91 tensor(90)
# path ./data/circle_255.npz tensor([91])
# 92 tensor(91)
# path ./data/circle_255.npz tensor([92])
# 93 tensor(92)
# path ./data/circle_255.npz tensor([93])
# 94 tensor(93)
# path ./data/circle_255.npz tensor([94])
# 95 tensor(94)
# path ./data/circle_255.npz tensor([95])
# 96 tensor(95)
# path ./data/circle_255.npz tensor([96])
# 97 tensor(96)
# path ./data/circle_255.npz tensor([97])
# 98 tensor(97)
# path ./data/circle_255.npz tensor([98])
# 99 tensor(98)
# path ./data/circle_255.npz tensor([99])
# 100 tensor(99)
# path ./data/circle_255.npz tensor([100])
# 101 tensor(100)
# path ./data/circle_255.npz tensor([101])
# 102 tensor(101)
# path ./data/circle_255.npz tensor([102])
# 103 tensor(102)
# path ./data/circle_255.npz tensor([103])
# 104 tensor(103)
# path ./data/circle_255.npz tensor([104])
# 105 tensor(104)
# path ./data/circle_255.npz tensor([105])
# 106 tensor(105)
# path ./data/circle_255.npz tensor([106])
# 107 tensor(106)
# path ./data/circle_255.npz tensor([107])
# 108 tensor(107)
# path ./data/circle_255.npz tensor([108])
# 109 tensor(108)
# path ./data/circle_255.npz tensor([109])
# 110 tensor(109)
# path ./data/circle_255.npz tensor([110])
# 111 tensor(110)
# path ./data/circle_255.npz tensor([111])
# 112 tensor(111)
# path ./data/circle_255.npz tensor([112])
# 113 tensor(112)
# path ./data/circle_255.npz tensor([113])
# 114 tensor(113)
# path ./data/circle_255.npz tensor([114])
# 115 tensor(114)
# path ./data/circle_255.npz tensor([115])
# 116 tensor(115)
# path ./data/circle_255.npz tensor([116])
# 117 tensor(116)
# path ./data/circle_255.npz tensor([117])
# 118 tensor(117)
# path ./data/circle_255.npz tensor([118])
# 119 tensor(118)
# path ./data/circle_255.npz tensor([119])
# 120 tensor(119)
# path ./data/circle_255.npz tensor([120])
# 121 tensor(120)
# path ./data/circle_255.npz tensor([121])
# 122 tensor(121)
# path ./data/circle_255.npz tensor([122])
# 123 tensor(122)
# path ./data/circle_255.npz tensor([123])
# 124 tensor(123)
# path ./data/circle_255.npz tensor([124])
# 125 tensor(124)
# path ./data/circle_255.npz tensor([125])
# 126 tensor(125)
# path ./data/circle_255.npz tensor([126])
# 127 tensor(126)
# path ./data/circle_255.npz tensor([127])
# 128 tensor(127)
# path ./data/circle_255.npz tensor([128])
# 129 tensor(128)
# path ./data/circle_255.npz tensor([129])
# 130 tensor(129)
# path ./data/circle_255.npz tensor([130])
# 131 tensor(130)
# path ./data/circle_255.npz tensor([131])
# 132 tensor(131)
# path ./data/circle_255.npz tensor([132])
# 133 tensor(132)
# path ./data/circle_255.npz tensor([133])
# 134 tensor(133)
# path ./data/circle_255.npz tensor([134])
# 135 tensor(134)
# path ./data/circle_255.npz tensor([135])
# 136 tensor(135)
# path ./data/circle_255.npz tensor([136])
# 137 tensor(136)
# path ./data/circle_255.npz tensor([137])
# 138 tensor(137)
# path ./data/circle_255.npz tensor([138])
# 139 tensor(138)
# path ./data/circle_255.npz tensor([139])
# 140 tensor(139)
# path ./data/circle_255.npz tensor([140])
# 141 tensor(140)
# path ./data/circle_255.npz tensor([141])
# 142 tensor(141)
# path ./data/circle_255.npz tensor([142])
# 143 tensor(142)
# path ./data/circle_255.npz tensor([143])
# 144 tensor(143)
# path ./data/circle_255.npz tensor([144])
# 145 tensor(144)
# path ./data/circle_255.npz tensor([145])
# 146 tensor(145)
# path ./data/circle_255.npz tensor([146])
# 147 tensor(146)
# path ./data/circle_255.npz tensor([147])
# 148 tensor(147)
# path ./data/circle_255.npz tensor([148])
# 149 tensor(148)
# path ./data/circle_255.npz tensor([149])
# 150 tensor(149)
# path ./data/circle_255.npz tensor([150])
# 151 tensor(150)
# path ./data/circle_255.npz tensor([151])
# 152 tensor(151)
# path ./data/circle_255.npz tensor([152])
# 153 tensor(152)
# path ./data/circle_255.npz tensor([153])
# 154 tensor(153)
# path ./data/circle_255.npz tensor([154])
# 155 tensor(154)
# path ./data/circle_255.npz tensor([155])
# 156 tensor(155)
# path ./data/circle_255.npz tensor([156])
# 157 tensor(156)
# path ./data/circle_255.npz tensor([157])
# 158 tensor(157)
# path ./data/circle_255.npz tensor([158])
# 159 tensor(158)
# path ./data/circle_255.npz tensor([159])
# 160 tensor(159)
# path ./data/circle_255.npz tensor([160])
# 161 tensor(160)
# path ./data/circle_255.npz tensor([161])
# 162 tensor(161)
# path ./data/circle_255.npz tensor([162])
# 163 tensor(162)
# path ./data/circle_255.npz tensor([163])
# 164 tensor(163)
# path ./data/circle_255.npz tensor([164])
# 165 tensor(164)
# path ./data/circle_255.npz tensor([165])
# 166 tensor(165)
# path ./data/circle_255.npz tensor([166])
# 167 tensor(166)
# path ./data/circle_255.npz tensor([167])
# 168 tensor(167)
# path ./data/circle_255.npz tensor([168])
# 169 tensor(168)
# path ./data/circle_255.npz tensor([169])
# 170 tensor(169)
# path ./data/circle_255.npz tensor([170])
# 171 tensor(170)
# path ./data/circle_255.npz tensor([171])
# 172 tensor(171)
# path ./data/circle_255.npz tensor([172])
# 173 tensor(172)
# path ./data/circle_255.npz tensor([173])
# 174 tensor(173)
# path ./data/circle_255.npz tensor([174])
# 175 tensor(174)
# path ./data/circle_255.npz tensor([175])
# 176 tensor(175)
# path ./data/circle_255.npz tensor([176])
# 177 tensor(176)
# path ./data/circle_255.npz tensor([177])
# 178 tensor(177)
# path ./data/circle_255.npz tensor([178])
# 179 tensor(178)
# path ./data/circle_255.npz tensor([179])
# 180 tensor(179)
# path ./data/circle_255.npz tensor([180])
# 181 tensor(180)
# path ./data/circle_255.npz tensor([181])
# 182 tensor(181)
# path ./data/circle_255.npz tensor([182])
# 183 tensor(182)
# path ./data/circle_255.npz tensor([183])
# 184 tensor(183)
# path ./data/circle_255.npz tensor([184])
# 185 tensor(184)
# path ./data/circle_255.npz tensor([185])
# 186 tensor(185)
# path ./data/circle_255.npz tensor([186])
# 187 tensor(186)
# path ./data/circle_255.npz tensor([187])
# 188 tensor(187)
# path ./data/circle_255.npz tensor([188])
# 189 tensor(188)
# path ./data/circle_255.npz tensor([189])
# 190 tensor(189)
# path ./data/circle_255.npz tensor([190])
# 191 tensor(190)
# path ./data/circle_255.npz tensor([191])
# 192 tensor(191)
# path ./data/circle_255.npz tensor([192])
# 193 tensor(192)
# path ./data/circle_255.npz tensor([193])
# 194 tensor(193)
# path ./data/circle_255.npz tensor([194])
# 195 tensor(194)
# path ./data/circle_255.npz tensor([195])
# 196 tensor(195)
# path ./data/circle_255.npz tensor([196])
# 197 tensor(196)
# path ./data/circle_255.npz tensor([197])
# 198 tensor(197)
# path ./data/circle_255.npz tensor([198])
# 199 tensor(198)
# path ./data/circle_255.npz tensor([199])
# 200 tensor(199)
# path ./data/circle_255.npz tensor([200])
# 201 tensor(200)
# path ./data/circle_255.npz tensor([201])
# 202 tensor(201)
# path ./data/circle_255.npz tensor([202])
# 203 tensor(202)
# path ./data/circle_255.npz tensor([203])
# 204 tensor(203)
# path ./data/circle_255.npz tensor([204])
# 205 tensor(204)
# path ./data/circle_255.npz tensor([205])
# 206 tensor(205)
# path ./data/circle_255.npz tensor([206])
# 207 tensor(206)
# path ./data/circle_255.npz tensor([207])
# 208 tensor(207)
# path ./data/circle_255.npz tensor([208])
# 209 tensor(208)
# path ./data/circle_255.npz tensor([209])
# 210 tensor(209)
# path ./data/circle_255.npz tensor([210])
# 211 tensor(210)
# path ./data/circle_255.npz tensor([211])
# 212 tensor(211)
# path ./data/circle_255.npz tensor([212])
# 213 tensor(212)
# path ./data/circle_255.npz tensor([213])
# 214 tensor(213)
# path ./data/circle_255.npz tensor([214])
# 215 tensor(214)
# path ./data/circle_255.npz tensor([215])
# 216 tensor(215)
# path ./data/circle_255.npz tensor([216])
# 217 tensor(216)
# path ./data/circle_255.npz tensor([217])
# 218 tensor(217)
# path ./data/circle_255.npz tensor([218])
# 219 tensor(218)
# path ./data/circle_255.npz tensor([219])
# 220 tensor(219)
# path ./data/circle_255.npz tensor([220])
# 221 tensor(220)
# path ./data/circle_255.npz tensor([221])
# 222 tensor(221)
# path ./data/circle_255.npz tensor([222])
# 223 tensor(222)
# path ./data/circle_255.npz tensor([223])
# 224 tensor(223)
# path ./data/circle_255.npz tensor([224])
# 225 tensor(224)
# path ./data/circle_255.npz tensor([225])
# 226 tensor(225)
# path ./data/circle_255.npz tensor([226])
# 227 tensor(226)
# path ./data/circle_255.npz tensor([227])
# 228 tensor(227)
# path ./data/circle_255.npz tensor([228])
# 229 tensor(228)
# path ./data/circle_255.npz tensor([229])
# 230 tensor(229)
# path ./data/circle_255.npz tensor([230])
# 231 tensor(230)
# path ./data/circle_255.npz tensor([231])
# 232 tensor(231)
# path ./data/circle_255.npz tensor([232])
# 233 tensor(232)
# path ./data/circle_255.npz tensor([233])
# 234 tensor(233)
# path ./data/circle_255.npz tensor([234])
# 235 tensor(234)
# path ./data/circle_255.npz tensor([235])
# 236 tensor(235)
# path ./data/circle_255.npz tensor([236])
# 237 tensor(236)
# path ./data/circle_255.npz tensor([237])
# 238 tensor(237)
# path ./data/circle_255.npz tensor([238])
# 239 tensor(238)
# path ./data/circle_255.npz tensor([239])
# 240 tensor(239)
# path ./data/circle_255.npz tensor([240])
# 241 tensor(240)
# path ./data/circle_255.npz tensor([241])
# 242 tensor(241)
# path ./data/circle_255.npz tensor([242])
# 243 tensor(242)
# path ./data/circle_255.npz tensor([243])
# 244 tensor(243)
# path ./data/circle_255.npz tensor([244])
# 245 tensor(244)
# path ./data/circle_255.npz tensor([245])
# 246 tensor(245)
# path ./data/circle_255.npz tensor([246])
# 247 tensor(246)
# path ./data/circle_255.npz tensor([247])
# 248 tensor(247)
# path ./data/circle_255.npz tensor([248])
# 249 tensor(248)
# path ./data/circle_255.npz tensor([249])
# 250 tensor(249)
# path ./data/circle_255.npz tensor([250])
# 251 tensor(250)
# path ./data/circle_255.npz tensor([251])
# 252 tensor(251)
# path ./data/circle_255.npz tensor([252])
# 253 tensor(252)
# path ./data/circle_255.npz tensor([253])
# 254 tensor(253)
# path ./data/circle_255.npz tensor([254])
# 255 tensor(254)
# path ./data/circle_255.npz tensor([255])
# (torch.Size([1, 3, 512, 512]), torch.Size([1, 3, 512, 512]))

# %%
square_no = 3
blueprint = Blueprint(stl_path, 512)
print(blueprint)
torch.save(blueprint.paths, f'./data/circle_plane_{len(blueprint.paths)}.pth')
blueprint_path = './data/circle_{}.npz'.format(square_no)
# print(blueprint_path)
res = blueprint.grid_sample(square_no, blueprint_path)
res['points'].shape, res['normals'].shape
# Out:
# 0 512
# 1 512
# 2 512
# 3 512
# 4 512
# 5 512
# 6 512
# 7 512
# 8 512
# 9 512
# 10 512
# 11 512
# 12 512
# 13 512
# 14 512
# 15 512
# 16 512
# 17 512
# 18 512
# 19 512
# 20 512
# 21 512
# 22 512
# 23 512
# 24 512
# 25 512
# 26 512
# 27 512
# 28 512
# 29 512
# 30 512
# 31 512
# 32 512
# 33 512
# 34 512
# 35 512
# 36 512
# 37 512
# 38 512
# 39 512
# 40 512
# 41 512
# 42 512
# 43 512
# 44 512
# 45 512
# 46 512
# 47 512
# 48 512
# 49 512
# 50 512
# 51 512
# 52 512
# 53 512
# 54 512
# 55 512
# 56 512
# 57 512
# 58 512
# 59 512
# 60 512
# 61 512
# 62 512
# 63 512
# 64 512
# 65 512
# 66 512
# 67 512
# 68 512
# 69 512
# 70 512
# 71 512
# 72 512
# 73 512
# 74 512
# 75 512
# 76 512
# 77 512
# 78 512
# 79 512
# 80 512
# 81 512
# 82 512
# 83 512
# 84 512
# 85 512
# 86 512
# 87 512
# 88 512
# 89 512
# 90 512
# 91 512
# 92 512
# 93 512
# 94 512
# 95 512
# 96 512
# 97 512
# 98 512
# 99 512
# 100 512
# 101 512
# 102 512
# 103 512
# 104 512
# 105 512
# 106 512
# 107 512
# 108 512
# 109 512
# 110 512
# 111 512
# 112 512
# 113 512
# 114 512
# 115 512
# 116 512
# 117 512
# 118 512
# 119 512
# 120 512
# 121 512
# 122 512
# 123 512
# 124 512
# 125 512
# 126 512
# 127 512
# 128 512
# 129 512
# 130 512
# 131 512
# 132 512
# 133 512
# 134 512
# 135 512
# 136 512
# 137 512
# 138 512
# 139 512
# 140 512
# 141 512
# 142 512
# 143 512
# 144 512
# 145 512
# 146 512
# 147 512
# 148 512
# 149 512
# 150 512
# 151 512
# 152 512
# 153 512
# 154 512
# 155 512
# 156 512
# 157 512
# 158 512
# 159 512
# 160 512
# 161 512
# 162 512
# 163 512
# 164 512
# 165 512
# 166 512
# 167 512
# 168 512
# 169 512
# 170 512
# 171 512
# 172 512
# 173 512
# 174 512
# 175 512
# 176 512
# 177 512
# 178 512
# 179 512
# 180 512
# 181 512
# 182 512
# 183 512
# 184 512
# 185 512
# 186 512
# 187 512
# 188 512
# 189 512
# 190 512
# 191 512
# 192 512
# 193 512
# 194 512
# 195 512
# 196 512
# 197 512
# 198 512
# 199 512
# 200 512
# 201 512
# 202 512
# 203 512
# 204 512
# 205 512
# 206 512
# 207 512
# 208 512
# 209 512
# 210 512
# 211 512
# 212 512
# 213 512
# 214 512
# 215 512
# 216 512
# 217 512
# 218 512
# 219 512
# 220 512
# 221 512
# 222 512
# 223 512
# 224 512
# 225 512
# 226 512
# 227 512
# 228 512
# 229 512
# 230 512
# 231 512
# 232 512
# 233 512
# 234 512
# 235 512
# 236 512
# 237 512
# 238 512
# 239 512
# 240 512
# 241 512
# 242 512
# 243 512
# 244 512
# 245 512
# 246 512
# 247 512
# 248 512
# 249 512
# 250 512
# 251 512
# 252 512
# 253 512
# 254 512
# 255 512
# 256 512
# 257 512
# 258 512
# 259 512
# 260 512
# 261 512
# 262 512
# 263 512
# 264 512
# 265 512
# 266 512
# 267 512
# 268 512
# 269 512
# 270 512
# 271 512
# 272 512
# 273 512
# 274 512
# 275 512
# 276 512
# 277 512
# 278 512
# 279 512
# 280 512
# 281 512
# 282 512
# 283 512
# 284 512
# 285 512
# 286 512
# 287 512
# 288 512
# 289 512
# 290 512
# 291 512
# 292 512
# 293 512
# 294 512
# 295 512
# 296 512
# 297 512
# 298 512
# 299 512
# 300 512
# 301 512
# 302 512
# 303 512
# 304 512
# 305 512
# 306 512
# 307 512
# 308 512
# 309 512
# 310 512
# 311 512
# 312 512
# 313 512
# 314 512
# 315 512
# 316 512
# 317 512
# 318 512
# 319 512
# 320 512
# 321 512
# 322 512
# 323 512
# 324 512
# 325 512
# 326 512
# 327 512
# 328 512
# 329 512
# 330 512
# 331 512
# 332 512
# 333 512
# 334 512
# 335 512
# 336 512
# 337 512
# 338 512
# 339 512
# 340 512
# 341 512
# 342 512
# 343 512
# 344 512
# 345 512
# 346 512
# 347 512
# 348 512
# 349 512
# 350 512
# 351 512
# 352 512
# 353 512
# 354 512
# 355 512
# 356 512
# 357 512
# 358 512
# 359 512
# 360 512
# 361 512
# 362 512
# 363 512
# 364 512
# 365 512
# 366 512
# 367 512
# 368 512
# 369 512
# 370 512
# 371 512
# 372 512
# 373 512
# 374 512
# 375 512
# 376 512
# 377 512
# 378 512
# 379 512
# 380 512
# 381 512
# 382 512
# 383 512
# 384 512
# 385 512
# 386 512
# 387 512
# 388 512
# 389 512
# 390 512
# 391 512
# 392 512
# 393 512
# 394 512
# 395 512
# 396 512
# 397 512
# 398 512
# 399 512
# 400 512
# 401 512
# 402 512
# 403 512
# 404 512
# 405 512
# 406 512
# 407 512
# 408 512
# 409 512
# 410 512
# 411 512
# 412 512
# 413 512
# 414 512
# 415 512
# 416 512
# 417 512
# 418 512
# 419 512
# 420 512
# 421 512
# 422 512
# 423 512
# 424 512
# 425 512
# 426 512
# 427 512
# 428 512
# 429 512
# 430 512
# 431 512
# 432 512
# 433 512
# 434 512
# 435 512
# 436 512
# 437 512
# 438 512
# 439 512
# 440 512
# 441 512
# 442 512
# 443 512
# 444 512
# 445 512
# 446 512
# 447 512
# 448 512
# 449 512
# 450 512
# 451 512
# 452 512
# 453 512
# 454 512
# 455 512
# 456 512
# 457 512
# 458 512
# 459 512
# 460 512
# 461 512
# 462 512
# 463 512
# 464 512
# 465 512
# 466 512
# 467 512
# 468 512
# 469 512
# 470 512
# 471 512
# 472 512
# 473 512
# 474 512
# 475 512
# 476 512
# 477 512
# 478 512
# 479 512
# 480 512
# 481 512
# 482 512
# 483 512
# 484 512
# 485 512
# 486 512
# 487 512
# 488 512
# 489 512
# 490 512
# 491 512
# 492 512
# 493 512
# 494 512
# 495 512
# 496 512
# 497 512
# 498 512
# 499 512
# 500 512
# 501 512
# 502 512
# 503 512
# 504 512
# 505 512
# 506 512
# 507 512
# 508 512
# 509 512
# 510 512
# 511 512
# Blueprint: ./data/circle.stl latitudes_num: 512
# 0 tensor(-1)
# path ./data/circle_3.npz tensor([0])
# 1 tensor(0)
# path ./data/circle_3.npz tensor([1])
# 2 tensor(1)
# path ./data/circle_3.npz tensor([2])
# 3 tensor(2)
# path ./data/circle_3.npz tensor([3])
# (torch.Size([1, 3, 8, 8]), torch.Size([1, 3, 8, 8]))

# %%
import trimesh

from src.utilities.util import make_faces

res = np.load('./data/circle_{}.npz'.format(square_no))
points = torch.tensor(res['points'])
_, _, w, h,  = points.shape
faces = make_faces(w, h)
faces.shape

b_vertices = points.squeeze().reshape(3, -1).t()
print(b_vertices.shape)

mesh = trimesh.Trimesh(vertices=b_vertices, faces=faces)
mesh.show()

mesh.export('./data/m{}.stl'.format(square_no));
# Out:
# torch.Size([64, 3])

# %%
res['points'].shape, res['normals'].shape

# %%
square_no = 1023
blueprint_path = './data/vezuvio{}.npz'.format(square_no)
# print(blueprint_path)
res = blueprint.grid_sample(square_no, blueprint_path)
res['points'].shape, res['normals'].shape

# %%
res = np.load('./data/vezuvio127.npz')#['points']#.shape

# %%
import trimesh

from src.utilities.util import make_faces

res = np.load('./data/vezuvio127.npz')
points = torch.tensor(res['points'])
_, _, w, h,  = points.shape
faces = make_faces(w, h)
faces.shape

b_vertices = points.squeeze().reshape(3, -1).t()
print(b_vertices.shape)

mesh = trimesh.Trimesh(vertices=b_vertices, faces=faces)
mesh.show()

mesh.export('./m3.stl');

# %%
square_no = 1
blueprint_path = './data/blueprint_radial_{}.npz'.format((square_no + 1) * 2)
print(blueprint_path)
res = blueprint.grid_sample(square_no, blueprint_path)
res['points'].shape, res['normals'].shape

# %%
square_no = 1
side = (square_no + 1) * 2
side

# %%
square_no = 1
side = (square_no + 1) * 2
side

# %%
square_no = 2
side = (square_no + 1) * 2
side

# %%
# 01
# 1
0.5
# 0123
# 1
# 2
# 3
1.5
# 012345
2.5
def get_angle(x, y, square_no):
    side = (square_no + 1) * 2
    corr = (side -1) / 2    
    angle = atan2(y -corr, x -corr)
    return angle if angle >= 0 else angle + 2 * pi

get_angle(0, 0, 0)

# %%
res['points']

# %%
sq_no, square_no = 0, 1
sq_ids = shifted_square_indices(sq_no, square_no)   
sq_ids

# %%
angle = get_angle(1, 2)
angle

# %%
for lat_angle in  blueprint.paths.keys():
    print(lat_angle)

# %%
keys = list(blueprint.paths.keys())
len(keys)

# %%
len(keys[:-1])

# %%
4098 % 4096

# %%
def get_border_paths(angle, paths):
    assert angle >=0 and angle < 2 * pi
    angle_keys = list(paths.keys())
    for i, angle_key in enumerate(angle_keys):        
        if angle < angle_key:            
            return (paths[angle_keys[i % len(keys)]],
                    paths[angle_keys[(i+1) % len(keys)]])
    return (paths[angle_keys[0]], paths[angle_keys[-1]])

angle = get_angle(1, 2)
paths = blueprint.paths
path0, path1 = get_border_paths(angle, paths)
path0, path1

# %%
angle = 6.291651496887207
path0, path1 = get_border_paths(angle, paths)
path0, path1

# %%
angle = 0
path0, path1 = get_border_paths(angle, paths)
path0, path1

# %%
angle = -0.1
path0, path1 = get_border_paths(angle, paths)
path0, path1

# %%
pnt0, nrm0 = single_path_sample(path0, sq_no, square_no)
pnt1, nrm1 = single_path_sample(path1, sq_no, square_no)

# %%
pnt0, nrm0

# %%
pnt0, pnt1, (pnt0 + pnt1)/2

# %%
import torch.nn.functional as F

# %%
F.normalize(nrm0, dim=0)
